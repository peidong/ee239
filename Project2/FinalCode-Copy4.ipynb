# %% [markdown]
# ### Project 2
# This explanation are mainly from different sections of the scikit-learn tutorial on text classification available at http://scikit-learn.org.

# %% [markdown]
# ### Dataset
# 1. In this project we work with “20 Newsgroups” dataset. It is a collection of approximately 20,000 newsgroup documents, partitioned (nearly) evenly across 20 different newsgroups, each corresponding to a different topic.
# 2. To manually load the data, you need to run this python code.<a href="https://www.dropbox.com/s/5oek8qbsge1y64b/fetch_data.py?dl=0">link to fetch_data.py</a>
# 3. Easiest way to load the data is to use the built-in dataset loader for 20 newsgroups from scikit-learn package.

# %% [markdown]
# ### Problem (a)

# %%
from sklearn.datasets import fetch_20newsgroups
categories = ['comp.graphics','rec.autos']
twenty_train = fetch_20newsgroups(subset='train', categories=categories, shuffle=True, random_state=42)
twenty_test = fetch_20newsgroups(subset='test', categories=categories, shuffle=True, random_state=42)

# %%
from sklearn.feature_extraction.text import CountVectorizer
def get_Number(fileName):
    count_vect = CountVectorizer()
    categories = [fileName]
    comp_graphic_train = fetch_20newsgroups(subset='train', categories=categories)
    comp_graphics_number = count_vect.fit_transform(comp_graphic_train.data)
    #print("(number of documents, number of features) = (%s, %s) " % comp_graphics_number.shape)
    [r,v] = comp_graphics_number.shape
    return r

comp_graphics_number = get_Number('comp.graphics')
comp_os_mswindows_misc_number = get_Number('comp.os.ms-windows.misc')
comp_sys_ibm_pc_hardware_number = get_Number('comp.sys.ibm.pc.hardware')
comp_sys_mac_hardware_number = get_Number('comp.sys.mac.hardware')
rec_autos_number = get_Number('rec.autos')
rec_motorcycles_number = get_Number('rec.motorcycles')
rec_sport_baseball_number = get_Number('rec.sport.baseball')
rec_sport_hockey_number = get_Number('rec.sport.hockey')

# %%
Number_Computer_technology = comp_graphics_number+comp_os_mswindows_misc_number+comp_sys_ibm_pc_hardware_number+comp_sys_mac_hardware_number
Number_Recreational_activity = rec_autos_number+rec_motorcycles_number+rec_sport_baseball_number+rec_sport_hockey_number

print("Number of class is = %s" % Number_Computer_technology)
print("Number of class is = %s" % Number_Recreational_activity)

import numpy as np
import matplotlib.pyplot as plt

n_groups = 8

document_number = (comp_graphics_number, comp_os_mswindows_misc_number, comp_sys_ibm_pc_hardware_number, comp_sys_mac_hardware_number, rec_autos_number, rec_motorcycles_number, rec_sport_baseball_number, rec_sport_hockey_number)

# fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.4
# Out:
# Number of class is = 2343
# Number of class is = 2389

# %%
objects = ('graphics', 'misc', 'pc.Hardware', 'mac.hardware', 'autos', 'motorcycles','baseball','hocky')
y_pos = np.arange(len(objects))

# %matplotlib inline
plt.figure()
plt.bar(y_pos, document_number, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Numbers')
plt.title('The number of documents')
plt.show()

# %% [markdown]
# ### Problem (b)

# %%
from sklearn.feature_extraction import text
import string
#from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.datasets import fetch_20newsgroups
stop_words = text.ENGLISH_STOP_WORDS.union(string.punctuation)

# %%
twenty_train = fetch_20newsgroups(subset='train', shuffle=True, random_state=42, remove = ('headers', 'footers','quotes'))
twenty_test = fetch_20newsgroups(subset='test', shuffle=True, random_state=42, remove = ('headers', 'footers','quotes'))

# %% [markdown]
# The converse mapping from feature name to column index is stored in the vocabulary_ attribute of the vectorizer:

# %%
import nltk
import re
import string

from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()




#import regex as re
stopwords = nltk.corpus.stopwords.words('english')
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("english")
def remove_punctuation(text):
    return re.sub(r'[^A-Za-z]', " ", text)
def tokenize_and_stem(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
   # stop_words = text.ENGLISH_STOP_WORDS.union(string.punctuation)
    tokens =[word for sent in nltk.sent_tokenize(remove_punctuation(text)) for word in nltk.word_tokenize(sent)]
#     print tokens
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]{2,}', token):
            filtered_tokens.append(token)
    for token in filtered_tokens:
        if token in stop_words:
             filtered_tokens.remove(token)
    for token in filtered_tokens:
        if token in stopwords:
             filtered_tokens.remove(token)              
    print filtered_tokens        
    stems = [wordnet_lemmatizer.lemmatize(t) for t in filtered_tokens]
    #print stems
    return stems

# %%
count_vect = TfidfVectorizer(tokenizer=tokenize_and_stem,min_df=1,stop_words= stop_words, token_pattern='[a-zA-Z]{2,}')
# count_vect = CountVectorizer(min_df=1, stop_words= stop_words, token_pattern='[a-zA-Z]{2,}')
# X_train_counts = count_vect.fit_transform(stemmed)
X_train_counts = count_vect.fit_transform(twenty_train.data)
print X_train_counts.shape
#X_train_counts
#print(X_train_counts[0,3949])
#0, 6035
#print count_vect.get_feature_names()
# Out:
# [u'wondering', u'anyone', u'enlighten', u'car', u'saw', u'day', u'door', u'sports', u'car', u'looked', u'late', u'early', u'called', u'bricklin', u'doors', u'really', u'small', u'addition', u'front', u'bumper', u'separate', u'rest', u'body', u'know', u'anyone', u'tellme', u'model', u'engine', u'specs', u'years', u'production', u'car', u'made', u'history', u'whatever', u'info', u'on', u'funky', u'looking', u'car', u'mail']
# [u'fair', u'number', u'brave', u'souls', u'upgraded', u'si', u'clock', u'oscillator', u'shared', u'experiences', u'poll', u'send', u'brief', u'message', u'detailing', u'experiences', u'procedure', u'speed', u'attained', u'cpu', u'rated', u'speed', u'add', u'cards', u'adapters', u'heat', u'sinks', u'hour', u'usage', u'day', u'floppy', u'disk', u'functionality', u'floppies', u'especially', u'requested', u'summarizing', u'two', u'days', u'please', u'add', u'network', u'knowledge', u'base', u'done', u'clock', u'upgrade', u'haven', u'answered', u'poll', u'thanks']
# [u'folks', u'mac', u'plus', u'finally', u'gave', u'ghost', u'weekend', u'starting', u'life', u'way', u'sooo', u'market', u'new', u'machine', u'bit', u'sooner', u'intended', u'looking', u'picking', u'powerbook', u'maybe', u'bunch', u'questions', u'hopefully', u'somebody', u'answer', u'anybody', u'know', u'dirt', u'next', u'round', u'powerbook', u'introductions', u'expected', u'heard', u'supposed', u'make', u'appearence', u'summer', u'haven', u'heard', u'anymore', u'since', u'access', u'macleak', u'wondering', u'anybody', u'more', u'info', u'anybody', u'heard', u'rumors', u'price', u'drops', u'powerbook', u'line', u'like', u'ones', u'duo', u'went', u'recently', u'impression', u'display', u'probably', u'swing', u'got', u'mb', u'disk', u'don', u'really', u'feel', u'better', u'display', u'yea', u'looks', u'great', u'store', u'wow', u'it', u'really', u'good', u'solicit', u'opinions', u'people', u'use', u'day', u'day', u'worth', u'taking', u'disk', u'size', u'money', u'hit', u'get', u'active', u'display', u'realize', u'real', u'subjective', u'question', u've', u'played', u'machines', u'computer', u'store', u'breifly', u'figured', u'opinions', u'somebody', u'actually', u'uses', u'machine', u'daily', u'prove', u'helpful', u'well', u'hellcats', u'perform', u'thanks', u'bunch', u'advance', u'info', u'you', u'email', u'll', u'post', u'summary', u'news', u'reading', u'time', u'at', u'premium', u'finals', u'the', u'corner', u'tom', u'willis', u'twillis', u'ecn', u'purdue', u'edu', u'purdue', u'electrical', u'engineering']
# [u'weitek', u'address', u'phone', u'number', u'like', u'get', u'information', u'chip']
# [u'article', u'owcb', u'world', u'std', u'com', u'tombaker', u'world', u'std', u'com', u'tom', u'baker', u'understanding', u'expected', u'errors', u'basically', u'known', u'bugs', u'warning', u'software', u'things', u'checked', u'don', u'right', u'values', u'yet', u'aren', u'set', u'till', u'launch', u'suchlike', u'fix', u'code', u'possibly', u'introduce', u'new', u'bugs', u'just', u'tell', u'crew', u'ok', u'warning', u'liftoff', u'ignore']
# [u'course', u'term', u'rigidly', u'defined', u'doubt', u'uses', u'term', u'are', u'using', u'quote', u'allegedly', u'you', u'read', u'article', u'presenting', u'argument', u'weapons', u'mass', u'destruction', u'commonly', u'understood', u'switching', u'topics', u'first', u'point', u'evidently', u'all', u'weapons', u'allowed', u'later', u'analysis', u'given', u'understanding', u'consider', u'class']
# [u'people', u'responded', u'request', u'info', u'treatment', u'astrocytomas', u'email', u'couldn', u'thank', u'directly', u'mail', u'bouncing', u'probs', u'sean', u'debra', u'sharon', u'thought', u'publicly', u'thank', u'thanks', u'sure', u'glad', u'accidentally', u'hit', u'rn', u'instead', u'rm', u'trying', u'delete', u'file', u'september', u'hmmm', u'news']
# [u'shows', u'know', u'scsi', u'scsi', u'scsi', u'controler', u'chip', u'range', u'mb', u'right', u'scsi', u'scsi', u'scsi', u'controller', u'chip', u'mb', u'mb', u'burst', u'bit', u'note', u'increase', u'speed', u'mac', u'quadra', u'uses', u'version', u'scsi', u'exist', u'pc', u'use', u'set', u'scsi', u'bit', u'scsi', u'mode', u'mb', u'mb', u'burst', u'scsi', u'bit', u'wide', u'fast', u'mode', u'mb', u'mb', u'burst', u'scsi', u'bit', u'wide', u'fast', u'mb', u'mb', u'burst', u'data', u'although', u'scsi', u'twice', u'fast', u'esdi', u'correct', u'scsi', u'controller', u'chip', u'scsi', u'reach', u'mb', u'indeed', u'faster', u'ide', u'these', u'scsi', u'facts', u'been', u'posted', u'newsgroup', u'mac', u'ibm', u'info', u'sheet', u'available', u'ftp', u'sumex', u'aim', u'stanford', u'edu', u'info', u'mac', u'report', u'mac', u'ibm', u'compare', u'version', u'txt', u'but', u'still', u'of', u'problem', u'mac', u'ibm', u'pc', u'inconsiant', u'what', u'scsi', u'well', u'documented', u'quadra', u'scsi', u'chip', u'apple', u'salesperson', u'said', u'uses', u'fast', u'scsi', u'chip', u'mb', u'mb', u'burst', u'does', u'scsi', u'mb', u'maximum', u'synchronous', u'quadra', u'uses', u'ansynchronous', u'scsi', u'slower', u'seems', u'mac', u'ibm', u'scsi', u'interface', u'think', u'scsi', u'maybe', u'scsi', u'interface', u'driven', u'the', u'machine', u'scsi', u'controller', u'chip', u'bit', u'mode', u'is', u'faster', u'true', u'scsi', u'go']
# [u'win', u'downloaded', u'icons', u'bmp', u'figure', u'change', u'wallpaper', u'use', u'icons', u'help', u'appreciated', u'thanx', u'brando']
# [u've', u'board', u'year', u'work', u'diskdoubler', u'autodoubler', u'licensing', u'problem', u'stac', u'technologies', u'owners', u'board', u'compression', u'technology', u'writing', u'memory', u've', u'lost', u'reference', u'correct', u'wrong', u'using', u'board', u've', u'problems', u'file', u'icons', u'lost', u'hard', u'say', u'board', u'fault', u'something', u'however', u'decompress', u'troubled', u'file', u'recompress', u'without', u'board', u'icon', u'usually', u'reappears', u'above', u'mentioned', u'licensing', u'problem', u'freeware', u'expansion', u'utility', u'dd', u'expand', u'decompress', u'board', u'compressed', u'file', u'unless', u'board', u'installed', u'stac', u'product', u'unlikely', u'holes', u'autodoubler', u'diskdoubler', u'related', u'the', u'board', u'fixed', u'sad', u'makes', u'reluctant', u'buy', u'stac', u'product', u'being', u'stinky', u'hey', u'competition']
# [u'line', u'ducati', u'gts', u'model', u'clock', u'runs', u'well', u'paint', u'bronze', u'brown', u'orange', u'faded', u'leaks', u'bit', u'oil', u'pops', u'st', u'hard', u'accel', u'shop', u'fix', u'trans', u'oil', u'leak', u'sold', u'bike', u'only', u'owner', u'want', u'thinking', u'like', u'opinions', u'email', u'thanks', u'would', u'nice', u'stable', u'mate', u'beemer', u'll', u'jap', u'bike', u'call', u'axis', u'motors', u'tuba', u'irwin', u'honk', u'computrac', u'richardson', u'tx', u'irwin', u'cmptrc', u'lonestar', u'org', u'dod']
# [u'yep', u'pretty', u'jew', u'understand', u'jewish', u'way', u'thinking', u'jews', u'believe', u'covenant', u'yhwh', u'patriarchs', u'abraham', u'moses', u'case', u'establishes', u'moral', u'code', u'follow', u'mankind', u'jews', u'decide', u'boundaries', u'fall', u'understand', u'sadducees', u'believed', u'torah', u'required', u'pharisees', u'ancestors', u'modern', u'judaism', u'believed', u'torah', u'available', u'interpretation', u'lead', u'understanding', u'required', u'morality', u'nuances', u'talmud', u'essence', u'biblical', u'morality', u'interface', u'man', u'yhwh', u'jew', u'christian', u'necessarily', u'indicate', u'yhwh', u'outside', u'relationship', u'speculate', u'trouble', u'really', u'know', u'created', u'image', u'means', u've', u'heard', u'number', u'different', u'opinions', u'come', u'conclusion', u'rather', u'upsets', u'apple', u'cart', u'one', u'wants', u'base', u'life', u'script', u'shaky', u'foundation', u'mix', u'metaphors', u'unashamedly', u'living', u'christ', u'example', u'know', u'little', u'jesus', u'person', u'recorded', u'utterances', u'set', u'narratives', u'followers', u'small', u'references', u'comtemporary', u'historians', u'revelation', u'aside', u'one', u'know', u'christ', u'second', u'hand', u'worse', u'not', u'attempt', u'debunk', u'christianity', u'seem', u'way', u'initially', u'point', u'trying', u'make', u'only', u'really', u'bible', u'interpret', u'interpretation', u'humanity', u'guess', u'this', u'faith', u'relevation', u'comes', u'all', u'inherent', u'subjectiveness', u'absolute', u'moral', u'code', u'undoubtably', u'multiple', u'moral', u'codes', u'multiple', u'moral', u'codes', u'founded', u'absolute', u'moral', u'code', u'example', u'parent', u'tell', u'child', u'swear', u'child', u'assume', u'parent', u'swears', u'simply', u'parent', u'told', u'child', u'wrong', u'parent', u'swear', u'like', u'trooper', u'pub', u'bar', u'are', u'children', u'wrongness', u'child', u'disobeys', u'parent', u'parent', u'feel', u'it', u'inappropriate', u'swear', u'front', u'children', u'may', u'quite', u'happy', u'swear', u'front', u'animals', u'analogy', u'not', u'quite', u'hold', u'water', u'child', u'knows', u'the', u'type', u'the', u'parent', u'may', u'parent', u'later', u'life', u'the', u'gist', u'it', u'incidentally', u'the', u'young', u'child', u'considers', u'the', u'directive', u'absolute', u'he', u'gets', u'older', u'piaget', u'learns', u'morality', u'his', u'david', u'religion']
# []
# [u'description', u'external', u'tank', u'option', u'ssf', u'redesign', u'deleted', u'yo', u'ken', u'let', u'things', u'external', u'tank', u'wingless', u'orbiter', u'options', u'deleted', u'ssf', u'redesign', u'options', u'list', u'today', u'edition', u'new', u'york', u'times', u'reports', u'connor', u'told', u'panel', u'redesign', u'proposals', u'dropped', u'using', u'giant', u'external', u'fuel', u'tanks', u'used', u'launching', u'space', u'shuttles', u'building', u'station', u'existing', u'space', u'shuttle', u'wings', u'tail', u'removed', u'currently', u'options', u'considered', u'presented', u'advisory', u'panel', u'meeting', u'yesterday', u'reported', u'today', u'times', u'option', u'low', u'cost', u'modular', u'approach', u'option', u'studied', u'team', u'msfc', u'aside', u'ssf', u'redesign', u'teams', u'msfc', u'jsc', u'larc', u'supporting', u'srt', u'station', u'redesign', u'team', u'crystal', u'city', u'lerc', u'reston', u'folks', u'site', u'locations', u'helping', u'respective', u'teams', u'redesign', u'activities', u'key', u'features', u'option', u'uses', u'bus', u'modular', u'bus', u'developed', u'lockheed', u'qualified', u'sts', u'elv', u'bus', u'provides', u'propulsion', u'gn', u'communications', u'data', u'management', u'lockheed', u'developed', u'air', u'force', u'power', u'station', u'capability', u'obtained', u'shuttle', u'flights', u'ssf', u'solar', u'arrays', u'used', u'provide', u'kw', u'power', u'vehicle', u'flies', u'arrow', u'mode', u'optimize', u'microgravity', u'environment', u'shuttle', u'spacelab', u'missions', u'utilize', u'vehilce', u'power', u'source', u'day', u'missions', u'human', u'tended', u'capability', u'opposed', u'old', u'ssf', u'sexist', u'term', u'man', u'tended', u'capability', u'achieved', u'addition', u'common', u'module', u'modified', u'version', u'existing', u'ssf', u'lab', u'module', u'docking', u'ports', u'added', u'international', u'partners', u'labs', u'taking', u'place', u'nodes', u'ssf', u'shuttle', u'docked', u'station', u'day', u'missions', u'orbiter', u'provide', u'crew', u'habitability', u'eva', u'capability', u'international', u'human', u'tended', u'add', u'nasda', u'esa', u'modules', u'add', u'kw', u'power', u'permanent', u'human', u'presence', u'capability', u'add', u'rd', u'power', u'module', u'habitation', u'module', u'acrv', u'assured', u'crew', u'return', u'vehicle', u'option', u'space', u'station', u'freedom', u'derived', u'option', u'team', u'based', u'larc', u'lead', u'mike', u'griffin', u'option', u'looks', u'alot', u'like', u'existing', u'ssf', u'design', u'come', u'know', u'love', u'option', u'assumes', u'lightweight', u'external', u'tank', u'available', u'use', u'all', u'ssf', u'assembly', u'flights', u'option', u'also', u'number', u'flights', u'computed', u'inclination', u'orbit', u'both', u'options', u'build', u'occurs', u'six', u'phases', u'initial', u'research', u'capability', u'reached', u'flights', u'power', u'transferred', u'vehicle', u'orbiter', u'spacelab', u'visits', u'man', u'tended', u'capability', u'griffin', u'adopted', u'non', u'sexist', u'language', u'achieved', u'flights', u'lab', u'deployed', u'solar', u'power', u'module', u'provides', u'kw', u'power', u'permanent', u'human', u'presence', u'capability', u'occurs', u'flights', u'keeping', u'orbiter', u'orbit', u'use', u'acrv', u'sometimes', u'would', u'orbiters', u'orbit', u'acrv', u'second', u'comes', u'logistics', u'supply', u'two', u'fault', u'tolerance', u'capability', u'achieved', u'flights', u'addition', u'nd', u'power', u'module', u'thermal', u'control', u'radiator', u'propulsion', u'modules', u'flights', u'internationals', u'board', u'power', u'habitation', u'module', u'an', u'acrv', u'added', u'finish', u'assembly', u'flights', u'systems', u'currently', u'ssf', u'used', u'is', u'option', u'the', u'exception', u'the', u'data', u'management', u'major', u'changes']
# [u'reduced', u'prices', u'list', u'things', u'forsale', u'behalf', u'brother', u'moving', u'moved', u'offer', u'black', u'decker', u'duster', u'plus', u'portable', u'hand', u'vaccum', u'purchased', u'sr', u'dual', u'cassette', u'portable', u'player', u'fm', u'band', u'graphics', u'equalizer', u'high', u'speed', u'dubing', u'duo', u'tape', u'tape', u'deck', u'lost', u'treble', u'sound', u'bet', u'fixable', u'purchased', u'monolux', u'zoom', u'microscope', u'magnification', u'japan', u'includes', u'case', u'accessories', u'purchased', u'sunbeam', u'hair', u'dryer', u'dryer', u'put', u'head', u'know', u'ones', u'see', u'the', u'salons', u'ask', u'my', u'bro', u'purchased', u'everylast', u'speed', u'bag', u'leather', u'brand', u'new', u'used', u'osterizer', u'pusle', u'matic', u'blender', u'speeds', u'cookbook', u'years', u'old', u'purchased', u'binolux', u'binoculars', u'extra', u'wide', u'angle', u'ft', u'yds', u'case', u'new', u'proctor', u'silex', u'spray', u'steam', u'dry', u'iron', u'new', u'questions', u'contact', u'thru', u'mail', u'reply', u'expeditously', u'always', u'included', u'please', u'consider', u'lastly', u'reasonable', u'reasonable']
# [u'so', u'sure', u'look', u'happened', u'japanese', u'citizens', u'world', u'war', u'ii', u'prepared', u'say', u'let', u'round', u'people', u'stick', u'concentration', u'camp', u'trial', u'short', u'step', u'gassing', u'without', u'trial', u'seems', u'nazis', u'originally', u'intended', u'imprison', u'jews', u'final', u'solution', u'dreamt', u'partly', u'couldn', u'afford', u'run', u'camps', u'devastation', u'caused', u'goering', u'total', u'war', u'weren', u'gassed', u'generally', u'died', u'malnutrition', u'disease']
# [u'certainly', u'use', u'whenever', u'tiff', u'usually', u'works', u'well', u'point', u'philosophically', u'opposed', u'complexity', u'complexity', u'led', u'programs', u'poor', u'tiff', u'writers', u'making', u'bizarre', u'files', u'programs', u'inability', u'load', u'tiff', u'images', u'll', u'save', u'course', u'general', u'inability', u'interchange', u'images', u'different', u'environments', u'despite', u'fact', u'think', u'understand', u'tiff', u'saying', u'goes', u'worried', u'abuse', u'tiff', u'years', u'chalk', u'immense', u'unnecessary', u'complexity', u'format', u'words', u'tiff', u'spec', u'appendix', u'page', u'capitalized', u'emphasis', u'problem', u'sort', u'success', u'tiff', u'designed', u'powerful', u'flexible', u'expense', u'simplicity', u'takes', u'fair', u'effort', u'handle', u'the', u'options', u'currently', u'defined', u'specification', u'probably', u'application', u'complete', u'job', u'currently', u'the', u'only', u'way', u'sure', u'you', u'able', u'import', u'tiff', u'image', u'image', u'generating', u'applications', u'if', u'program', u'worse', u'applications', u'read', u'tiff', u'image', u'means', u'are', u'won', u'deal', u'want', u'images', u'to', u'be', u'trapped', u'that', u'format', u'neither', u'agrees', u'reasoning', u'that', u'anyone', u'of', u'course']
# [u'recently', u'posted', u'article', u'asking', u'kind', u'rates', u'single', u'male', u'drivers', u'yrs', u'old', u'paying', u'performance', u'cars', u'summary', u'replies', u'received', u'anymore', u'close', u'dodge', u'stealth', u'rt', u'twin', u'turbo', u'hp', u'model', u'tickets', u'accidents', u'house', u'taken', u'defensive', u'driving', u'airbag', u'abs', u'security', u'alarm', u'single', u'year', u'decut', u'state', u'farm', u'insurance', u'includes', u'additional', u'umbrella', u'policy', u'car', u'house', u'base', u'policy', u'standard', u'policy', u'required', u'de', u'nd', u'defensive', u'driving', u'course', u'bought', u'car', u'september', u'company', u'accident', u'ticket', u'years', u'quoted', u'hope', u'helps', u'steve', u'flynn', u'university', u'delaware', u'kevin', u'hope', u'remembered', u'name', u'correctly', u'asked', u'insurance', u'performance', u'cars', u'year', u'similar', u'situation', u'bought', u'car', u'inquiry', u'age', u'car', u'eagle', u'talon', u'tsi', u'awd', u'driving', u'record', u'clean', u'state', u'illinois', u'cost', u'mos', u'turn', u'may', u'insurance', u'goes', u'mos', u'single', u'incurs', u'higher', u'rate', u'company', u've', u'got', u'couple', u'friends', u'awds', u'pay', u'different', u'ins', u'companies', u'maybe', u'lucky', u'hope', u'info', u'helps', u'dan', u'dans', u'jdc', u'gss', u'mot', u'com', u'motorola', u'cellular', u'subscriber', u'group', u'usa', u'cc', u'live', u'norman', u'oklahoma', u'drive', u'thunderbird', u'sc', u'never', u'made', u'claim', u'insurance', u'hit', u'times', u'negligent', u'drivers', u'couldn', u'stop', u'signs', u'fiddling', u'radios', u'three', u'moving', u'violations', u'last', u'months', u'going', u'failure', u'clear', u'intersection', u'say', u'damn', u'light', u'yellow', u'going', u'didn', u'record', u'rates', u'state', u'farm', u'passive', u'restraint', u'deduction', u'liability', u'deductible', u'comprehensive', u'deductible', u'collision', u'roughly', u'year', u'paying', u'year', u'escort', u'lx', u'james', u'james', u'callison', u'microcomputer', u'coordinator', u'oklahoma', u'law', u'center', u'callison', u'uokmax', u'ecn', u'uoknor', u'edu', u'callison', u'aardvark', u'ucs', u'uoknor', u'edu', u'disclaimer', u'engineer', u'play', u'work', u'forecast', u'calls', u'thunder', u'bird', u'sc', u'hell', u'thing', u'killing', u'man', u'take', u'away', u'he', u'gon', u'na', u'munny', u'unforgiven', u'beyond', u'age', u'group', u'experience', u'years', u'ago', u'might', u'interesting', u'owned', u'toyota', u'celica', u'gt', u'decided', u'buy', u'gift', u'exotic', u'car', u'runners', u'included', u'toyota', u'supra', u'turbo', u'porsche', u'model', u'years', u'narrowed', u'those', u'liked', u'simplicity', u'handling', u'snob', u'appeal', u'driving', u'porsche', u'supra', u'turbo', u'less', u'money', u'features', u'performance', u'personal', u'luxury', u'car', u'better', u'acceleration', u'higher', u'speed', u'almost', u'ready', u'give', u'buying', u'impulse', u'decided', u'stop', u'insurance', u'agent', u'office', u'way', u'asked', u'happen', u'rate', u'car', u'buy', u'supra', u'rate', u'classification', u'celica', u'celica', u'considered', u'subcompact', u'year', u'rated', u'safest', u'cars', u'slight', u'increase', u'car', u'years', u'newer', u'lower', u'risk', u'division', u'continue', u'handle', u'account', u'buy', u'porsche', u'll', u'change', u'standard', u'higher', u'rate', u'company', u'rate', u'double', u'story', u'll', u'cover', u'rest', u'year', u'cancel', u'supra', u'faster', u'actually', u'faster', u'standard', u'doens', u'make', u'sense', u'book', u'says', u'insure', u'corvettes', u'either', u'reason', u'underwriters', u'consider', u'supras', u'drivers', u'traditional', u'conservative', u'eventually', u'went', u'supra', u'number', u'reasons', u'porsche', u'dealer', u'nice', u'salesman', u'interested', u'tough', u'high', u'pressure', u'guy', u'room', u'equal', u'monthly', u'payments', u'taken', u'year', u'longer', u'pay', u'porsc ...
# [u'like', u'able', u'amplify', u'voltage', u'signal', u'output', u'thermocouple', u'preferably', u'factor', u'resulting', u'voltage', u'fed', u'easily', u'personal', u'computer', u'based', u'adc', u'data', u'acquisition', u'card', u'anyone', u'able', u'point', u'references', u'circuits', u'seen', u'simple', u'amplifier', u'circuits', u'not', u'sure', u'well', u'work', u'practice', u'case', u'like', u'amplify', u'sufficiently', u'nicely', u'be', u'used', u'thermocouples', u'say', u'degrees', u'accuracy', u'better']
# [u'question', u'exact', u'entry', u'parameter', u'syntax', u'terminal', u'configuration', u'file', u'loaded', u'terminal', u'boots', u'add', u'system', u'tcp', u'ip', u'access', u'control', u'list', u'background', u'two', u'unix', u'systems', u'running', u'mit', u'sun', u'ss', u'want', u'window', u'sun', u'ncd', u'terminal', u'time', u'if', u'manually', u'set', u'network', u'parameter', u'tcp', u'ip', u'access', u'control', u'list', u'login', u'telnet', u'session', u'great', u've', u'tried', u'get', u'xhost', u'work', u'failed', u'syntax', u'wrong', u'implementation', u'bogus', u'trying', u'edit', u'ncd', u'configuration', u'file', u'loaded', u'ncd', u'boots', u'matter', u'entry', u'add', u'edit', u'ncd', u'boots', u'the', u'tcp', u'ip', u'access', u'control', u'list', u'containing', u'the', u'my', u'manuals', u'worthless', u'help', u'appreciated', u'thanks']
# [u'like', u'little', u'things', u'least', u'orders', u'worse', u'motto', u'think', u'motto', u'little', u'thing', u'lead', u'worse', u'things']
# [u'think', u'mike', u'foligno', u'captain', u'sabres', u'got', u'traded', u'leafs', u'wasn', u'rick', u'vaive', u'captain', u'leafs', u'got', u'traded', u'chicago', u'steve', u'thomas', u'ed', u'olcyzk', u'someone', u'speaking', u'leafs', u'believe', u'darryl', u'sittler', u'captain', u'torn', u'off', u'jersey', u'think', u're', u'claimed', u'captaincy', u'later', u'traded', u'flyers', u'oh', u'yeah', u'course', u'gretzky', u'captain', u'oilers', u'was', u'traded', u'wasn', u'he']
# [u'catalog', u'personal', u'computing', u'tools', u'engineers', u'scien', u'tists', u'lists', u'hardware', u'cards', u'application', u'software', u'packages', u'pc', u'xt', u'ps', u'class', u'machines', u'focus', u'engineering', u'scien', u'tific', u'applications', u'pcs', u'data', u'acquisition', u'control', u'design', u'automation', u'data', u'analysis', u'presentation', u'like', u'free', u'copy', u'reply', u'postal', u'mailing', u'address', u'copy', u'catalog', u'front', u'as', u'write', u'does', u'tons', u'qool', u'stuff', u'impression', u'try', u'send', u'out', u'browsers', u'appears', u'buyer', u'engineer', u'not', u'want', u'waste', u'catalog', u'catalog', u'vip', u'code', u'you', u'give', u'ensure', u'continued', u'subscription', u'if', u'you', u'want', u'get', u'touch', u'company', u'personal', u'computing', u'tools', u'division', u'street', u'campbell', u'ca', u'also', u'fax', u'toll', u'free', u'ordering', u'tech', u'support']
# [u'control', u'box', u'window', u'upper', u'left', u'corner', u'window', u'single', u'click', u'simplistic', u'font', u'option', u'is', u'biggest', u'use', u'characters', u'turning', u'funky']
# [u'know', u'specific', u'problem', u'mentioned', u'message', u'definitely', u'scsi', u'problems', u'venerable', u'jasmine', u'megadrive', u'cartridge', u'drives', u'solution', u'silverlining', u'loops', u'involved', u'blind', u'writes', u'worked', u'drives', u'fact', u'only', u'loop', u'worked', u'the', u'macintosh', u'software', u'loop', u'means']
# [u'hello', u'looking', u'add', u'voice', u'input', u'capability', u'user', u'interface', u'developing', u'hp', u'unix', u'workstation', u'greatly', u'appreciate', u'information', u'care', u'offer', u'voice', u'input', u'systems', u'easily', u'accessible', u'unix', u'environment', u'names', u'adresses', u'applicable', u'vendors', u'well', u'experiences', u'specific', u'systems', u'would', u'helpful', u'respond', u'email', u'post', u'summary', u'sufficient', u'thanks', u'ken', u'found', u'impressive', u'systems', u'ibm', u'pc', u'would', u'like', u'avoid', u'hassle', u'purchasing', u'maintaining', u'separate', u'pc', u'possible', u'ken', u'hinckley', u'kph', u'virginia', u'edu', u'university', u'virginia', u'neurosurgical', u'visualization', u'laboratory']
# [u'actually', u'fossil', u'fuel', u'plants', u'run', u'hotter', u'usual', u'boiling', u'water', u'reactor', u'nuclear', u'plants', u'gripe', u'industry', u'nuclear', u'power', u'uses', u'vintage', u'steam', u'technology', u'important', u'nuclear', u'plants', u'get', u'cold', u'end', u'cold', u'possible', u'big', u'cooling', u'towers', u'oil', u'gas', u'fired', u'steam', u'plants', u'condensers', u'usually', u'sized', u'get', u'steam', u'hot', u'water', u'way', u'ambient', u'plants', u'cool', u'condensers', u'water', u'air', u'one', u'canadian', u'official', u'asked', u'thermal', u'pollution', u'icing', u'river', u'said', u'view', u'heat', u'resource', u'everybody', u'runs', u'closed', u'cycle', u'boilers', u'water', u'used', u'purified', u'solids', u'otherwise', u'crud', u'boiler', u'plumbing', u'water', u'boils', u'purifying', u'water', u'boiler', u'use', u'bigger', u'job', u'cooling', u'so', u'the', u'boiler', u'water', u'recycled']
# [u'doug', u'roberts', u'ken', u'hill', u'nl', u'mvp', u'let', u'spos']
# [u'yes', u'adamantly', u'environmentalist', u'use', u'styrofoam', u'table', u'service', u'keep', u'mind', u'read', u'post', u'wish', u'attack', u'environmentalism', u'half', u'truth', u'dangerous', u'complete', u'lie', u'complete', u'lie', u'rarely', u'readily', u'accepted', u'half', u'truth', u'lie', u'subtly', u'hidden', u'powerfully', u'offered', u'masquerades', u'angel', u'light', u'satan', u'people', u'loosened', u'grip', u'treating', u'earth', u'god', u'intricate', u'handiwork', u'something', u'than', u'health', u'future', u'generations', u'based', u'treated', u'respect', u'think', u'going', u'happily', u'leave', u'no', u'one', u'error', u'rejected', u'style', u'push', u'people', u'opposite', u'error', u'earth', u'god', u'intricate', u'handiwork', u'rubbish', u'god', u'mother', u'earth', u'one', u'primarily', u'love', u'serve', u'two', u'facets', u'response', u'care', u'environment', u'treat', u'proper', u'respect', u'god', u'intricate', u'handiwork', u'health', u'future', u'generation', u'showing', u'facet', u'one', u'is', u'disregardful', u'things', u'constitute', u'apostle', u'paul', u'called', u'things', u'men', u'possible', u'means', u'save', u'say', u'forget', u'environment', u've', u'got', u'important', u'things', u'spend', u'time', u'putting', u'foot', u'mouth', u'manner', u'destroy', u'credibility', u'expressing', u'things', u'are', u'important', u'is', u'the', u'ultimate', u'entity', u'it', u'is', u'creature', u'not', u'creator', u'beauty', u'glory', u'points', u'greater', u'beauty', u'glory', u'it', u'is', u'not', u'the', u'ultimate', u'tapestry', u'one', u'many', u'cords', u'woven', u'the', u'infinite', u'tapestry']
# [u'depends', u'priorities', u'lot', u'people', u'higher', u'priorities', u'gas', u'mileage', u'cost', u'safety', u'buying', u'unsafe', u'econoboxes', u'instead', u'volvos', u'personally', u'middle', u'ground', u'thing', u'really', u'look', u'point', u'seatbelt', u'mph', u'bumpers', u'figure', u'mph', u'collisions', u'brick', u'walls', u'aren', u'common', u'spend', u'much', u'extra', u'money', u'protection', u'lots', u'low', u'speed', u'collisions', u'worry']
# [u'front', u'covers', u'available', u'sony', u'check', u'local', u'car', u'stereo', u'shop', u'probably', u'definitely', u'provide', u'units', u'serial', u'number', u'hopefully', u'registered', u'warranty', u'card', u'know', u'cost', u'replacements', u'available', u'people', u'damage', u'face', u'cover', u'stands', u'reason', u'be', u'replaced', u'deterring', u'theft', u'worked', u'stereo', u'shop', u'referred', u'customer', u'sony', u'number', u'sell', u'face', u'have', u'available', u'people', u'came', u'asking', u'face', u'cover', u'pullout', u'sleave', u'matter', u'would', u'look', u'disheartened', u'find', u'acquired', u'deck', u'couldn', u'use', u'theft', u'occurs', u'decks', u'notify', u'sony', u'serial', u'numbers', u'catch', u'theives']
# [u'son', u'usual', u'teenage', u'spotty', u'chin', u'greasy', u'nose', u'bought', u'clearasil', u'face', u'wash', u'ointment', u'think', u'probably', u'along', u'usual', u'good', u'diet', u'get', u'product', u'called', u'dalacin', u'used', u'doctor', u'prescription', u'treatment', u'available', u'chemist', u'counter', u'asked', u'couple', u'pharmacists', u'say', u'acne', u'severe', u'dalacin', u'clearasil', u'ok', u'odd', u'spots', u'teenager', u'serious', u'father', u'so', u'figure', u'acne', u'going', u'escalate', u'something', u'disfiguring', u'know', u'kids', u'senstitive', u'appearance', u'wary', u'neighbour', u'son', u'wierd', u'malady', u'was', u'eventually', u'an', u'overdose', u'vitamin', u'acne', u'treatment', u'want', u'help', u'appropriate', u'treatment', u'son', u'scaliness', u'hairline', u'scalp', u'sort', u'teenage', u'cradle', u'cap', u'pointers', u'advice', u'this', u'tried', u'couple', u'anti', u'dandruff', u'shampoos', u'these', u'inclined', u'make', u'condition', u'worse', u'better', u'shall', u'bury', u'kid', u'till']
# [u'not', u'possible', u'subject', u'understanding', u'exploding', u'televisions', u'major', u'cause', u'domestic', u'accidents', u'soviet', u'union', u'past', u'years']
# [u'define', u'war', u'seiges', u'constant', u'attacks', u'villiages', u'count', u'acts', u'war', u'jews', u'them', u'january', u'arab', u'liberation', u'army', u'attacks', u'kfar', u'szold', u'men', u'attack', u'kfar', u'etzion', u'miles', u'south', u'jerusalem', u'cutting', u'supply', u'lines', u'attacks', u'yehiam', u'western', u'galilee', u'kibbutz', u'tirat', u'tzvi', u'mid', u'march', u'jewish', u'settlements', u'negev', u'cut', u'land', u'links', u'rest', u'jewish', u'population', u'etzion', u'group', u'villiages', u'near', u'hebron', u'cut', u'members', u'convoy', u'trying', u'supply', u'yehiam', u'slaughtered', u'cutting', u'villiage', u'jerusalem', u'seige', u'cut', u'supply', u'route', u'tel', u'aviv', u'bombed', u'supply', u'trucks', u'left', u'road', u'day', u'memoriam', u'time', u'jews', u'killed', u'course', u'isn', u'war', u'only', u'arabs', u'attacking', u'like', u'week', u'fatah', u'launched', u'katyusha', u'rockets', u'northern', u'israel', u'uprising', u'end', u'war', u'begin', u'be', u'intifadah', u'plo', u'brings', u'tanks']
# [u'appears', u'eyed', u'man', u'appeared', u'land', u'sighted', u'strange', u'resaon', u'appointed', u'ruler', u'supreme', u'power']
# [u'funny', u'mention', u'one', u'time', u'hnic', u'cherry', u'pointed', u'vanbiesbrouck', u'mask', u'hated', u'think', u'said', u'effect', u'great', u'year', u'goes', u'gets', u'dopey', u'mask', u'he', u'stop', u'beachball', u'may', u'may', u'take', u'cherry', u'seriously', u'cracked', u'heard']
# [u'oh', u'boy', u'little', u'bike', u'versus', u'scuffling', u'grow', u'goes', u'hope', u'dump', u'dempster', u'campaign', u'works', u'think', u'crook', u'am', u'suprised', u'taken', u'long', u'anything', u'though', u'obviously', u'ain', u'yet', u'hand', u'sure', u'want', u'bed', u'wackos', u'running', u'throwing', u'oo', u'rathole', u'effective', u'sending', u'club', u'wouldn', u'anything', u'anything', u'magazine', u'say', u'since', u'the', u'moa', u'politburo', u'installed', u'has', u'lacked', u'sort', u'panache', u'may', u'ah', u'know', u'bike']
# [u'agree', u'assessment', u'furthermore', u'promotion', u'providing', u'greater', u'protection', u'bare', u'voice', u'quite', u'true', u'far', u'goes', u'way', u'fulfill', u'stated', u'goal', u'letting', u'le', u'wiretap', u'terrorists', u'drug', u'dealers', u'restrict', u'stronger', u'techniques', u'wiretap', u'targets', u'presently', u'use', u'strong', u'encryption', u'weak', u'encryption', u'vast', u'majority', u'encryption', u'latter', u'classes', u'tapped', u'weak', u'encryption', u'every', u'phone', u'encryption', u'class', u'merged', u'weak', u'encryption', u'class', u'introduction', u'clipper', u'cause', u'targets', u'presently', u'enjoying', u'strong', u'privacy', u'give', u'rely', u'privacy', u'system', u'expressly', u'designed', u'deny', u'people', u'like', u'doubt', u'mere', u'introduction', u'scheme', u'give', u'government', u'stated', u'goal', u'preventing', u'degradation', u'wiretapping', u'capabilities', u'fulfilled', u'restriction', u'domestic', u'cryptography', u'restriction', u'clipper', u'appears', u'no', u'sop', u'given', u'public', u'mute', u'complaints', u'would', u'grossly', u'inadequate', u'tradeoff', u'fear', u'public', u'large', u'care', u'hate', u'mention', u'gun', u'control', u'people', u'think', u'assault', u'weapon', u'nyt', u'uses', u'word', u'sort', u'automatic', u'weapon', u'caliber', u'maybe', u'wants', u'thing', u'legal', u'people', u'know', u'even', u'less', u'cryptology', u'suspect', u'strong', u'cryptography', u'easily', u'labeled', u'much', u'secrecy', u'law', u'abiding', u'citizens', u'need', u'say', u'opinion', u'do', u'matters', u'continue', u'unless', u'overturned', u'courts', u'reluctant', u'annul', u'law', u'regulation', u'going', u'some', u'length', u'decide', u'cases', u'grounds', u'furthermore', u'congress', u'get', u'away', u'quite', u'bit', u'levy', u'burdensome', u'tax', u'would', u'place', u'enforcement', u'hands', u'batf', u've', u'seen', u'really', u'want', u'your', u'case', u'could', u'invoke', u'commerce', u'clause', u'seems', u'likely', u'clause', u'get', u'anywhere', u'days', u'th', u'required', u'supreme', u'court', u'ruled', u'prohibitory', u'statute', u'unconstitutional', u'congress', u'prohibited', u'drugs', u'textual', u'nod', u'commerce', u'clause', u'controlled', u'substances', u'act', u'still', u'stands', u'think', u'the', u'government', u'could', u'get', u'away']
# [u'word', u'subrogation', u're', u'willing', u'wait', u'money', u'scumbag', u'insurance', u'save', u'pay', u'deductible', u'scumbag', u'insurance', u'scum', u'insurance', u'have', u'pay', u'deductible', u'get', u'insurance', u'pack', u'rabid', u'large', u'fanged', u'lawyers', u'recover', u'damages', u'scum', u'insurance', u'lawyers', u'sad', u'true', u'job', u'security', u'lawyers', u'later']
# [u'iftccu', u'talk', u'politics', u'guns', u'vincent', u'cad', u'gatech', u'edu', u'vincent', u'fox', u'apr', u'isn', u'rec', u'guns', u'maybe', u'getting', u'bet', u'technical', u'resist', u'depends', u'misfired', u'imagine', u'combat', u'type', u'shooting', u'single', u'action', u'assuming', u'cylinder', u'rotate', u'hurts', u'err', u'safety', u've', u'got', u'new', u'fangled', u'hammer', u'blocks', u'transfer', u'bar', u'safeties', u'unnecessarily', u'redundant', u'extra', u'round', u'quite', u'true', u'speed', u'loaders', u'little', u'convenient', u'pack', u'magazines', u'true', u'training', u'function', u'cocked', u'locked', u'single', u'actions', u'hammer', u'double', u'actions', u'carry', u'modes', u'make', u'sense', u'series', u'colt', u'example', u'quite', u'safe', u'carry', u'way', u'agreed', u've', u'shot', u'mouth', u'bit', u'let', u'back', u'true', u'simple', u'misfire', u'revolver', u'doesn', u'cost', u'much', u'hand', u've', u'sorts', u'interesting', u'things', u'happen', u'years', u'example', u've', u'factory', u'ammunition', u'high', u'primers', u'high', u'primer', u'tie', u'revolver', u'somewhere', u'seconds', u'minutes', u'try', u'pound', u'action', u'open', u'clear', u'problem', u'auto', u'jack', u'slide', u'continue', u've', u'bullets', u'come', u'case', u'keeping', u'cylinder', u'turning', u'clearing', u'paragraph', u'worst', u'happen', u'semi', u'auto', u'double', u'feed', u'cleared', u'seconds', u'revolvers', u'fragile', u'semi', u'auto', u'sorts', u'close', u'tolerance', u'parts', u'fitting', u'involved', u'dropping', u'gun', u'blow', u'gun', u'sorts', u'things', u'action', u'problems', u'cured', u'spot', u'quality', u'semi', u'auto', u'take', u'gun', u'smith', u'revolver', u'short', u'revolver', u'likely', u'malfunction', u'rule', u're', u'fight', u'majority', u'malfunctions', u'occur', u'semi', u'autos', u'fall', u'category', u'vincint', u'makes', u'good', u'points', u'post', u'leaves', u'opposing', u'view', u'real', u'good', u'starting', u'place', u'ayoob', u'semi', u'auto', u'pistol', u'police', u'self', u'defense', u'general', u'agree', u'revolver', u'excellent', u'gun', u'self', u'defense', u'weapon', u'somebody', u'does', u'time', u'inclination', u'necessary', u'training', u'practice', u'needed', u'use', u'semi', u'auto', u'effectively', u'self', u'defense', u'arm', u'cops', u'notoriously', u'indifferent', u'firearms', u'department', u'isn', u'going', u'train', u'they', u'aren', u'going', u'take', u'time', u'no', u'doubt', u'training', u'an', u'issue', u'amount', u'training', u'required', u'effective', u'use', u'semi', u'auto', u'probably', u'times', u'revolver', u'cops', u'bother', u'hate', u'limited', u'one', u'rather', u'pick', u'fits', u'better', u'personal', u'inclination', u'wearing', u'day', u'like', u'moderator', u'rec', u'guns', u'says', u'buy', u'em', u'said', u'have', u'admit', u'that', u'often', u'advice', u'people', u'thinking', u'of', u'buying', u'first', u'defense', u'arm', u'right', u'taking', u'class', u'ruger', u'smith', u'revolver', u'sorry', u'colt', u'fans', u'colt', u'revolvers', u'ok', u'this', u'post', u'gone', u'the', u'other', u'way', u'arguing', u'revolvers']
# [u'ted', u're', u'missing', u'vital', u'point', u'roger', u'lustig', u'pointed', u'previous', u'response', u'reason', u'schott', u'banned', u'baseball', u'known', u'call', u'think', u'racially', u'biased', u'manner', u'constant', u'basis', u'thoughts', u'affected', u'hiring', u'practices', u'bonilla', u'hand', u'found', u'mentioned', u'one', u'word', u'single', u'time', u'known', u'go', u'criticizing', u'homosexuals', u'different', u'story', u'furthermore', u'merely', u'athlete', u'doesn', u'hire', u'schott', u'dave', u'pallone', u'former', u'nl', u'umpire', u'admitted', u'homosexual', u'decided', u'assist', u'protest', u'mets', u'game', u'shea', u'like', u'thinks', u'bonilla', u'suspended', u'baseball', u'pallone', u'hoping', u'year', u'suspension', u'my', u'opinion', u'downright', u'ludicrous', u'howie', u'rose', u'wfan', u'said', u'start', u'suspending', u'athletes', u'mentioned', u'derogatory', u'word', u'single', u'time', u'whatever', u'conditions', u'probably', u'enough', u'people', u'remaining', u'play', u'game', u'honestly', u'truly', u'analyze', u'differences', u'cases', u'bring', u'article', u'would', u'think', u'reconsider', u'thoughts', u'sean']
# [u'using', u'home', u'office', u'bought', u'arounde', u'don', u'know', u'for', u'data', u'fax', u'feature', u'use', u'voic', u'mail', u'box', u'really', u'liked']
# [u'western', u'digital', u'sam']
# [u'second', u'straight', u'game', u'california', u'scored', u'ton', u'late', u'runs', u'crush', u'brewhas', u'runs', u'th', u'win', u'monday', u'five', u'th', u'six', u'th', u'win', u'yesterday', u'jamie', u'navarro', u'pitched', u'seven', u'strong', u'innings', u'orosco', u'austin', u'manzanillo', u'lloyd', u'took', u'mockery', u'bullpen', u'yesterday', u'numbers', u'maldanado', u'pitched', u'scoreless', u'innings', u'navarro', u'era', u'lowest', u'staff', u'wegman', u'ouch', u'doesn', u'look', u'better', u'hitters', u'hamilton', u'batting', u'thon', u'hitting', u'seven', u'rbi', u'next', u'highest', u'next', u'best', u'hitter', u'jaha', u'vaughn', u'team', u'hr', u'another', u'ouch', u'looking', u'stats', u'hard', u'see', u'team', u'fact', u'doesn', u'sound', u'bad', u'averaging', u'three', u'runs', u'game', u'giving', u'game', u'early', u'things', u'undoubtedly', u'better', u'offense', u'come', u'bullpen', u'major', u'worry', u'fetters', u'plesac', u'austin', u'gave', u'brewers', u'great', u'middle', u'relief', u'year', u'lloyd', u'maldanado', u'manzanillo', u'fetters', u'austin', u'orosco', u'pick', u'pace', u'team', u'successful', u'milwaukee', u'won', u'number', u'games', u'year', u'middle', u'relief', u'held', u'small', u'leads', u'kept', u'small', u'deficits', u'place', u'starters', u'okay', u'the', u'defense', u'alright', u'the', u'hitting', u'come', u'the', u'bullpen', u'big', u'question', u'mark', u'other', u'news', u'nilsson', u'doran', u'reactivated', u'yesterday', u'william', u'suero', u'sent', u'tim', u'mcintosh', u'picked', u'montreal', u'today', u'game', u'california', u'cancelled']
# [u'case', u'think', u'viola', u'better', u'signing', u'viola', u'younger', u'left', u'handed', u'many', u'left', u'handed', u'starters', u'toronto', u'well', u'agree', u'viola', u'better', u'signing', u'say', u'want', u'lefthanded', u'starters', u'understand', u'lefthanded', u'spot', u'relievers', u'though', u'usually', u'face', u'righthanded', u'batters', u'lefthanded', u'batters', u'don', u'understand', u'people', u'insist', u'lefthanded', u'starters', u'unless', u'park', u'effect', u'yankee', u'stadium', u'batters', u'mlb', u'righthanded', u'righthanded', u'starters', u'platoon', u'advantage', u'often', u'lefthanded', u'starters', u'guess', u'argument', u'lefty', u'starters', u'that', u'certain', u'teams', u'vulnerable', u'lhp', u'rhp', u'is', u'probably', u'factor', u'postseason', u'teams', u'seldom', u'juggle', u'starters', u'reason', u'regular', u'season', u'think', u'want', u'best', u'starters', u'can', u'regardless', u'whether', u'lefties', u'righties', u'lefthanded', u'starters', u'tend', u'higher', u'era', u'righthanded', u'starters', u'precisely', u'managers', u'their', u'way', u'start', u'inferior', u'lefties', u'perhaps', u'the', u'platoon', u'advantage', u'missing']
# [u'course', u'want', u'check', u'honesty', u'dealler', u'knowing', u'wrong', u'ask', u'tell', u'course', u'll', u'probably', u'know', u'right', u'way', u'charge', u'service', u'fee']
# [u'wyse', u'terminal', u'emulator', u'comms', u'toolbox', u'kit', u'available', u'net', u'thanks']
# [u'easy', u'rider', u'harleys', u'drugs', u'rednecks', u'new', u'orleans', u'mad', u'max', u'violence', u'dod', u'wan', u'na', u'time', u'rider', u'honda', u'thumper', u'time', u'travel', u'sunday', u'documentary', u'dirtbike', u'racers', u'great', u'great', u'escape', u'steve', u'mcqueen', u'nazis', u'rebel', u'cause', u'james', u'dean', u'future', u'dod', u'ers', u'think', u'last', u'right', u'old', u'movies', u'haven', u'seen', u'years', u'dod', u'technician', u'dr', u'speed', u'student']
# [u'subject', u'line', u'says', u'working', u'project', u'use', u'car', u'battery', u'need', u'pull', u'possibly', u'ideas', u'prefer', u'benefit', u'brilliant', u'people']
# [u'pat', u'sez', u'yeah', u'windscreen', u'cut', u'canopies', u'ended', u'completely', u'course', u'environment', u'space', u'continues', u'suck', u'tommy', u'mac', u'tom', u'mcwilliams', u'wk', u'radius', u'vision', u'increases', u'tm', u'ibm', u'cl', u'msu', u'edu', u'hm', u'circumference', u'mystery', u'grows']
# [u'trying', u'write', u'image', u'display', u'program', u'uses', u'mit', u'shared', u'memory', u'extension', u'shared', u'memory', u'segment', u'gets', u'allocated', u'attached', u'process', u'problem', u'program', u'crashes', u'call', u'xshmputimage', u'following', u'message', u'error', u'failed', u'request', u'badshmseg', u'invalid', u'shared', u'segment', u'parameter', u'major', u'opcode', u'failed', u'request', u'mit', u'shm', u'minor', u'opcode', u'failed', u'request', u'shmputimage', u'segment', u'id', u'failed', u'request', u'serial', u'number', u'failed', u'request', u'current', u'serial', u'number', u'output', u'stream', u'like', u'said', u'error', u'checking', u'calls', u'shmget', u'shmat', u'necessary', u'create', u'shared', u'memory', u'segment', u'well', u'checking', u'xshmattach', u'no', u'problems', u'anybody', u'the', u'problem', u'used', u'mit', u'shm', u'the', u'problem', u'let', u'know', u'the', u'way', u'running', u'openwindows', u'sun', u'sparc']
# [u'following', u'thread', u'talk', u'religion', u'soc', u'religion', u'christian', u'bible', u'study', u'interest', u'amazed', u'different', u'non', u'biblical', u'argument', u'oppose', u'sabbath', u'present', u'question', u'comes', u'mind', u'especially', u'one', u'answered', u'scripture', u'maybe', u'clh', u'wish', u'provide', u'first', u'response', u'lot', u'talk', u'sabbath', u'tc', u'ceremonial', u'answer', u'since', u'tc', u'commandments', u'one', u'law', u'ten', u'parts', u'biblical', u'basis', u'decided', u'sabbath', u'portion', u'ceremonial', u'say', u'seventh', u'day', u'sabbath', u'applicable', u'gentile', u'christians', u'mean', u'sabbath', u'commandment', u'annulled', u'references', u'god', u'not', u'intend', u'requirements', u'jews', u'applicable', u'gentile', u'christians', u'make', u'plain', u'the', u'gentiles', u'grafted', u'the', u'commonwealth', u'israel', u'darius']
# [u'hi', u'anyone', u'tell', u'get', u'copy', u'updated', u'canon', u'bj', u'printer', u'driver', u'windows', u'ver', u'comes', u'bj', u'printer', u'wonder', u'any', u'newer', u'version']
# [u'herman', u'think', u'people', u'could', u'distinguish', u'health', u'treatment', u'disease', u'prevention', u'medicine', u'people', u'preach', u'time', u'buy', u'health', u'buy', u'treatment', u'disease', u'assuming', u'lucky', u'disease', u'treated', u'rich', u'person', u'terminal', u'disease', u'bit', u'luck', u'such', u'thing', u'adequately', u'covered', u'will', u'what', u'worth', u'll', u'the', u'to', u'admit', u'patients', u'die']
# ...
# [u'got', u'ss', u'based', u'good', u'ratings', u'little', u'impressed', u'performance', u'mill', u'supposed', u'comparable', u'trident', u'unaccelerated', u'vga', u'came', u'ok', u'performance', u'winspeed', u'good', u'great', u'second', u'know', u'that', u'jpg', u'viewer', u'ss', u'saw', u'cica', u'something', u'it', u'work', u'better', u'thanks', u'help', u'greg']
# [u'radiosity', u'sources', u'wanted', u'read', u'comp', u'graphics', u'group', u'found', u'radiosity', u'anybody', u'interested', u'there', u'would', u'glad', u'hear', u'somebody', u'looking', u'source', u'code', u'radiosity', u'method', u'already', u'read', u'common', u'literature', u'foley', u'think', u'little', u'examples', u'help', u'understand', u'radiosity', u'works', u'common', u'languages', u'pascal', u'prefered', u'hope', u'help']
# [u'heading', u'true', u'mr', u'frank', u'ashamed', u'makes', u'gag', u'people', u'respect', u'rights', u'others', u'voice', u'opinions', u'idol', u'lenny', u'bruce', u'commented', u'asshole', u'time', u'magazine', u'advocated', u'censorship', u'material', u'time', u'actually', u'sided', u'cops', u'arresting', u'bruce', u'shows', u'routinely', u'say', u'cocksucker', u'cops', u'rush', u'stage', u'arrest', u'times', u'haven', u'changed', u'help', u'think', u'lenny', u'received', u'today', u'politically', u'correct', u'arena', u'heck', u'support', u'right', u'neo', u'nazis', u'speak', u'opinions', u'march', u'streets', u'mr', u'frank', u'anyone', u'makes', u'wisecracks', u'anti', u'semitism', u'jewish', u'longtime', u'member', u'aipac', u'jnf', u'contributed', u'apiece', u'fine', u'groups', u'regular', u'contributor', u'every', u'pro', u'israel', u'group', u'find', u'still', u'support', u'right', u'people', u'like', u'arf', u'speak', u'vomit', u'propaganda', u'want', u'know', u'people', u'basing', u'assumption', u'mr', u'frank', u'write', u'sysadmin', u'requesting', u'mr', u'teel', u'admonished', u'not', u'the', u'case', u'retract', u'these', u'nasties', u'directed', u'not', u'stand', u'mr', u'frank', u'his', u'trashing', u'the', u'amendment']
# [u'wonder', u'american', u'businesses', u'going', u'tubes', u'nist', u'nsa', u'nsa', u'supposed', u'didn', u'say', u'said', u'better', u'commercial', u'grade', u'encryptions', u'one', u'wouldn', u'trust', u'unless', u'they', u'release', u'algorithm', u'investigation', u'maybe', u'aclu', u'eff', u'non', u'profit', u'big', u'wouldn', u'trust', u'nsa', u'think', u'would', u'trust', u'president', u'certain', u'would', u'told', u'problem', u'want', u'emphasize', u'am', u'not', u'speaking', u'beckman', u'instruments', u'point', u'an', u'international', u'company', u'would', u'like', u'think', u'customers', u'come', u'ahead', u'government', u'whims']
# [u'question', u'related', u'jesus', u'condemns', u'divorce', u'times', u'new', u'testament', u'hard', u'time', u'catholic', u'church', u'far', u'tell', u'grant', u'annulments', u'statement', u'marriage', u'really', u'existed', u'god', u'eyes', u'mistinterpreting', u'correct', u'however', u'witnessed', u'marriages', u'two', u'people', u'love', u'recognized', u'destroying', u'staying', u'marriage', u'problems', u'due', u'personal', u'childhood', u'issues', u'been', u'resolved', u'ask', u'divorce', u'justified', u'case', u'knew', u'they', u'were', u'deeply', u'love', u'end', u'work', u'must', u'admit', u'jesus', u'forcing', u'live', u'condemning', u'they', u'seek', u'happiness', u'someone', u'later', u'opinions', u'vera', u'clock', u'bind', u'unto', u'today', u'vera', u'noyes', u'religion', u'the', u'strong', u'the', u'noye', u'midway', u'uchicago', u'edu', u'trinity', u'disclaimer', u'lard', u'st', u'patrick', u'breastplate', u'there', u'disclaim']
# [u'comet', u'shoemaker', u'levy', u'jovian', u'orbit', u'comet', u'still', u'hanging', u'galileo', u'arrives', u'sure', u'added', u'list', u'targets', u'll', u'over', u'years', u'earth', u'based', u'observations', u'help', u'narrow', u'positions', u'pieces', u'comet', u'probably', u'won', u'different', u'done', u'gaspra', u'galileo', u'image', u'toutatis', u'came', u'earth', u'based', u'radar']
# [u'help', u'running', u'sample', u'problems', u'reilly', u'volume', u'xt', u'intrisics', u'programming', u'manual', u'chapter', u'popup', u'dialog', u'boxes', u'example', u'page', u'creating', u'pop', u'dialog', u'box', u'application', u'creates', u'window', u'button', u'quit', u'press', u'button', u'press', u'pops', u'dialog', u'box', u'strange', u'feature', u'program', u'always', u'pops', u'dialog', u'box', u'faster', u'time', u'try', u'pop', u'nd', u'time', u'rd', u'th', u'time', u'slower', u'experience', u'sample', u'programs', u'this', u'behaviour', u'fast', u'response', u'time', u'first', u'time', u'slow', u'response', u'time', u'nd', u'time', u'onwards', u'anyone', u'me', u'ideas', u'program', u'popups', u'that', u'time', u'popup', u'reasonable', u'fast', u'response', u'time']
# [u'mean', u'damn', u'henrik', u'attempt', u'helpful', u'using', u'common', u'misconception', u'be', u'corrected', u'mach', u'banding', u'occur', u'image', u'color', u'quantization', u'see', u'don', u'enough', u'bits', u'human', u'eye', u'response', u'transitions', u'edges', u'intensities', u'result', u'that', u'colors', u'near', u'transistion', u'look', u'brighter', u'brighter', u'darker', u'darker', u'andre']
# [u'hey', u'folks', u've', u'got', u'pair', u'dunlop', u'sportmax', u'radials', u'zx', u've', u'sticky', u'slides', u'this', u'talk', u'metzelers', u'wondering', u'set', u'lazer', u'comp', u'radial', u'metzeler', u'rear', u'hard', u'sport', u'touring', u'the', u'choices', u'stack']
# [u'wharf', u'wrat', u'rites', u'while', u'reference', u'super', u'slab', u'interstate', u'defense', u'highways', u'whether', u'military', u'much', u'anything', u'goes', u'road', u'another', u'matter', u'whomped', u'diesel', u'trucks', u'maybe', u'load', u'permitting', u'military', u'surplus', u'stuff', u've', u'driven', u'jeep', u'classic', u'willys', u'kaiser', u'amc', u'pre', u'independent', u'suspension', u'power', u'wagons', u'slant', u'crew', u'cab', u'pickup', u'weren', u'exactly', u'congenial', u'highway', u'speeds', u'wouldn', u'swear', u'would', u'except', u'bedload', u'semi', u'got', u'ta', u'love', u'standard', u'military', u'tire', u'least', u'one', u'used', u'use', u'designed', u'circa', u'ww', u'ii', u'compromise', u'traction', u'icky', u'sticky', u'goo', u'longevity', u'sharp', u'rocks', u'forth', u'quite', u'ill', u'adapted', u'high', u'speeds', u'civilian', u'roadways', u'can', u'remember', u'look', u'like', u'imagine', u'mountain', u'bike', u'tire', u'road', u'rib', u'middle', u'scaled', u'car', u'size', u'oh', u'yeah', u'narrow', u'one', u'standard', u'mods', u'civilizing', u'surplus', u'jeep', u'install', u'tires', u'wheels', u'reflected', u'advancements', u'ride', u'handling', u'day', u'point', u'wharfie', u'others', u'still', u'stands', u'going', u'do', u'mil', u'spec', u'power', u'wagon', u'jeep', u'tank', u'transporter', u'unwieldy', u'rubber', u'tired', u'vehicle', u'suggest', u'american', u'interstate', u'safe', u'speed', u'tends', u'be', u'limited', u'car', u'skills', u'road', u'maintenance', u'swarms', u'fools', u'the', u'roads', u'designed', u'going', u'like', u'the', u'devil', u'naturally', u'employer', u'advocates', u'unsafe', u'unlawful', u'driving']
# [u'title', u'says', u'particularly', u'interested', u'performance', u'difference', u'much', u'faster', u'centris', u'lciii', u'tom']
# [u'know', u'reading', u'something', u'did', u'make', u'sence', u'wondering', u'someone', u'help', u'say', u'provided', u'paragraph', u'shall', u'unlawful', u'person', u'transfer', u'possess', u'machinegun', u'got', u'looking', u'law', u'dictionary', u'found', u'person', u'also', u'artificial', u'entity', u'created', u'government', u'rights', u'federal', u'constitution', u'don', u'understand', u'statute', u'like', u'enforced', u'individual', u'someone', u'tell', u'how', u'my', u'government', u'tell', u'or', u'possess', u'passing', u'law', u'make', u'law', u'knows', u'laws', u'constitional', u'goes', u'court', u'gone', u'court', u'just', u'run', u'ok', u'it', u'guilty', u'jail', u'anyone', u'ever', u'claimed', u'right', u'possess', u'told', u'supreme', u'court', u'didn', u'right']
# [u'sherri', u'agree', u'kiddies', u'sense', u'spew', u'obscenities', u'front', u'group', u'adults', u'try', u'edit', u'newsgroup', u'feed', u'local', u'elementary', u'schools', u'group', u'students', u'love', u'baseball', u'learning', u'use', u'computers', u'telling', u'gotten', u'point', u'edit', u'files', u'anymore', u'read', u'throw', u'trash', u'thanks', u'people', u'think', u'wonderful', u'include', u'swear', u'word', u'two', u'signature', u'files', u'really', u'nice', u'read', u'whole', u'article', u'toss', u'the', u'sig', u'me', u'wrong', u'know', u'the', u'words', u've', u'made', u'of', u'or', u'wouldn', u'able', u'edit', u'out', u'just', u'doesn', u'the', u'place', u'public', u'forum', u'spew', u'foul', u'language', u'sorry', u'thanks', u'all', u'people', u'keep', u'mind', u'might', u'decent', u'young', u'people', u'interested', u'baseball', u'computers', u'reading', u'newsgroup', u'enjoy', u'articles']
# [u'windows', u'shareware', u'monthly', u'wsm', u'line', u'forum', u'information', u'newest', u'best', u'windows', u'nt', u'shareware', u'freeware', u'software', u'wsm', u'compilation', u'submissions', u'shareware', u'freeware', u'authors', u'single', u'windows', u'hlp', u'help', u'file', u'types', u'software', u'submitted', u'entry', u'wsm', u'utilities', u'applications', u'games', u'programming', u'tools', u'wsm', u'benefits', u'windows', u'shareware', u'freeware', u'authors', u'allowing', u'publicize', u'software', u'releases', u'inform', u'users', u'updated', u'versions', u'increase', u'installed', u'base', u'users', u'searching', u'specific', u'windows', u'software', u'benefit', u'complete', u'list', u'available', u'software', u'available', u'fingertips', u'complete', u'feature', u'lists', u'current', u'prices', u'relevant', u'information', u'windows', u'software', u'authors', u'submit', u'entries', u'windows', u'shareware', u'monthly', u'following', u'manner', u'compose', u'short', u'summary', u'function', u'software', u'include', u'special', u'features', u'unique', u'product', u'set', u'apart', u'programs', u'genre', u'sure', u'include', u'specific', u'details', u'current', u'release', u'version', u'software', u'available', u'much', u'registration', u'fee', u'costs', u'much', u'disk', u'space', u'required', u'special', u'requirements', u'sound', u'card', u'vbrun', u'dll', u'author', u'contacted', u'text', u'highly', u'compressible', u'summary', u'long', u'necessary', u'best', u'keep', u'short', u'good', u'guideline', u'single', u'screenful', u'point', u'text', u'resolution', u'order', u'forms', u'addendum', u'included', u'desired', u'submissions', u'whould', u'plain', u'text', u'ascii', u'format', u'formatting', u'exactly', u'submitted', u'simply', u'cut', u'paste', u'text', u'files', u'help', u'authoring', u'require', u'special', u'formatting', u'conventions', u'boldface', u'text', u'italics', u'larger', u'font', u'size', u'indicate', u'clearly', u'text', u'file', u'best', u'results', u'use', u'windows', u'notepad', u'create', u'txt', u'file', u'include', u'windows', u'format', u'bmp', u'bitmap', u'screen', u'shots', u'display', u'workings', u'special', u'features', u'program', u'special', u'cases', u'rendering', u'applications', u'example', u'require', u'color', u'bitmaps', u'submit', u'bmp', u'files', u'observe', u'limit', u'use', u'color', u'format', u'maximum', u'compatiblity', u'software', u'used', u'create', u'wsm', u'hlp', u'file', u'stefan', u'olson', u'help', u'writer', u'assistant', u'windows', u'save', u'bitmaps', u'windows', u'paintbrush', u'wingif', u'include', u'color', u'bmp', u'program', u'icon', u'ico', u'file', u'programs', u'available', u'convert', u'ico', u'bmp', u'format', u'windows', u'paintbrush', u'used', u'bmp', u'embedded', u'summary', u'text', u'double', u'check', u'spelling', u'errors', u'formatting', u'corrections', u'compress', u'txt', u'file', u'bmp', u'program', u'icon', u'additional', u'bmps', u'single', u'file', u'using', u'pkzip', u'version', u'submit', u'entry', u'uuencoding', u'zipfile', u'mailing', u'daa', u'tamuts', u'tamu', u'edu', u'submitting', u'internet', u'compuserve', u'submitting', u'america', u'online', u'send', u'brief', u'message', u'indicating', u'submission', u'append', u'zip', u'file', u'mail', u'diegoaa', u'changes', u'required', u'new', u'version', u'released', u'complete', u'procedures', u'send', u'submissions', u'tamuts', u'address', u'comments', u'suggestions', u'criticisms', u'daa', u'rigel', u'tamu', u'edu', u'entries', u'received', u'deadline', u'included', u'subsequent', u'edition', u'wsm', u'editor', u'held', u'responsible', u'errors', u'reserve', u'right', u'make', u'changes', u'entries', u'wsm', u'limited', u'shareware', u'freeware', u'software', u'special', u'area', u'devoted', u'commercially', u'available', u'windows', u'nt', u'software', u'commercial', u'software', u'authors', u'follow', u'steps', u'exception', u'limitations', u'size', u'txt', u'file',  ...
# [u'think', u'unrealistic', u'suppose', u'federal', u'agencies', u'fail', u'promptly', u'comply', u'court', u'order', u'good', u'point', u'local', u'law', u'enforcement', u'unable', u'perform', u'wiretap', u'bringing', u'federal', u'agencies', u'based', u'possibly', u'incomplete', u'understanding', u'quoted', u'denning', u'fbi', u'able', u'decrypt', u'system', u'key', u'encryption', u'layer', u'seems', u'needed', u'identify', u'escrowed', u'keys', u'request', u'moves', u'great', u'deal', u'law', u'enforcement', u'power', u'federal', u'level', u'the', u'reason', u'like', u'point', u'that', u'may', u'sway', u'even', u'persuade', u'people', u'generally', u'line', u'the', u'civil', u'liberties', u'crowd', u'national', u'police', u'force', u'opposed', u'people', u'broad', u'range', u'political', u'viewpoints']
# [u'thanks', u'topic', u'wider', u'audience', u'making', u'decision', u'intend', u'prevent', u'private', u'sector', u'developing', u'government', u'approval', u'microcircuits', u'algorithms', u'effective', u'assuring', u'privacy']
# [u'short', u'reply', u'achieve', u'perfect', u'health', u'strive', u'seek', u'god', u're', u'forced', u'follow', u'way', u'way', u'best', u'reason', u'hard', u'flawed', u'unreasonable', u'we', u'seek', u'follow', u'way', u'we', u'want', u'improve', u'lives']
# [u'racetrack', u'original', u'statement', u'nonsense', u'believe', u'legislate', u'morality', u'simply', u'stated', u'pass', u'laws', u'want', u'single', u'make', u'moral', u'people', u'may', u'make', u'act', u'moral', u'manner', u'actions', u'reflection', u'unwillingness', u'risk', u'punishment', u'say', u'we', u'become', u'moral', u'not', u'the', u'distinction', u'fine', u'tog']
# [u'gives', u'keys', u'fbi', u'may', u'give', u'local', u'police', u'request', u'simply', u'alagator', u'clips', u'phone', u'junction', u'box', u'conduct', u'illegal', u'tap', u'decrypt', u'recover', u'tape', u'doing', u'government', u'best', u'breaking', u'law']
# [u'they', u'anyway', u'mean', u'smart', u'make', u'job', u'easier', u'day', u'christmas', u'truelove', u'served', u'leftover', u'turkey', u'the', u'second', u'day', u'christmas', u'truelove', u'served', u'turkey', u'casserole', u'from', u'leftover', u'turkey', u'days', u'deleted', u'flaming', u'turkey', u'wings', u'pizza', u'hut', u'commercial', u'tlu', u'gic', u'bait']

# %%
#from sklearn.feature_extraction.text import TfidfTransformer
#tfidf_transformer = TfidfTransformer()
#X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
#print (X_train_tfidf)
# X_train_tfidf.toarray()[:30,:10]

# %%
#nltk.download()

# %% [markdown]
# ### Problem (c)

# %%
def get_max_feature(fileName):
    categories = [fileName]
    twenty_train_c = fetch_20newsgroups(subset='train', categories=categories, shuffle=True, random_state=42)
    count_vect_c = TfidfVectorizer(tokenizer=tokenize_and_stem,min_df=1,max_features=10, stop_words= stop_words, token_pattern='[a-zA-Z]{2,}')
#     count_vect_c = TfidfVectorizer(min_df=1, max_features=10, stop_words= stop_words, token_pattern='[a-zA-Z]{2,}')
    X_train_counts_c = count_vect_c.fit_transform(twenty_train_c.data)
    return count_vect_c.vocabulary_.keys()


print (get_max_feature('comp.sys.ibm.pc.hardware'))
print (get_max_feature('comp.sys.mac.hardware'))
print (get_max_feature('misc.forsale'))
print (get_max_feature('soc.religion.christian'))

# %% [markdown]
# ### Problem (d)

# %%
from sklearn.decomposition import TruncatedSVD
tsv = TruncatedSVD(n_components=50,algorithm='arpack')
X_train_lsi = tsv.fit_transform(X_train_counts)
print (X_train_lsi.shape)
# Out:
# (11314, 50)

# %% [markdown]
# ### Problem (e)

# %%
categories = ['comp.graphics','comp.os.ms-windows.misc','comp.sys.ibm.pc.hardware','comp.sys.mac.hardware','rec.autos','rec.motorcycles','rec.sport.baseball','rec.sport.hockey']
twenty_train = fetch_20newsgroups(subset='train', categories=categories, shuffle=True, random_state=42, remove = ('headers', 'footers','quotes'))
twenty_test = fetch_20newsgroups(subset='test', categories=categories, shuffle=True, random_state=42, remove = ('headers', 'footers','quotes'))

twenty_train_target = [ int(x / 4) for x in twenty_train.target]
twenty_test_target = [ int(x / 4) for x in twenty_test.target]
#print twenty_test_target
#count_vect = TfidfVectorizer(min_df=1, stop_words= stop_words, token_pattern='[a-zA-Z]{2,}')
#X_train_counts = count_vect.fit_transform(twenty_train.data)
#print twenty_train.target
#print twenty_train_target

# %%
def data_process(twenty_test):
#     count_vect_test = TfidfVectorizer(min_df=1, stop_words= stop_words, token_pattern='[a-zA-Z]{2,}')
    count_vect_test = TfidfVectorizer(tokenizer=tokenize_and_stem,min_df=2,stop_words= stop_words, token_pattern='[a-zA-Z]{2,}')
    X_test_counts = count_vect_test.fit_transform(twenty_test.data)
    tsv_test = TruncatedSVD(n_components=50,algorithm='arpack')
    X_test_lsi = tsv_test.fit_transform(X_test_counts)
    return X_test_lsi

# %%
from sklearn.svm import LinearSVC
X_train_lsi=data_process(twenty_train)
clf = LinearSVC(C=10e20).fit(X_train_lsi, twenty_train_target)

# %%
X_test_lsi = data_process(twenty_test)
predicted = clf.predict(X_test_lsi)
print predicted
score = clf.score(X_test_lsi, twenty_test_target)
print score
# Out:
# [0 0 1 ..., 1 0 0]
# 0.78253968254

# %%
from sklearn.metrics import roc_curve, auc
y_score=clf.decision_function(X_test_lsi)
fpr, tpr, _ = roc_curve(twenty_test_target, y_score)
#average_precision = average_precision_score(twenty_test.target, y_score)
roc_auc = auc(fpr, tpr)


plt.figure()
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-d4994d252543> in <module>()
#       6
#       7
# ----> 8 plt.figure()
#       9 plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
#      10 plt.plot([0, 1], [0, 1], 'k--')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ##### Confusion matrix. [Reference Link](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html)

# %%
from sklearn.metrics import confusion_matrix
y_true = twenty_test_target
y_pred = predicted
print confusion_matrix(y_true, y_pred)
# Out:
# [[1106  454]
#  [ 231 1359]]

# %% [markdown]
# ##### Accuracy [Reference Link](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html)

# %%
from sklearn.metrics import accuracy_score
y_true = twenty_test_target
y_pred = predicted
print accuracy_score(y_true, y_pred)
# Out:
# 0.78253968254

# %% [markdown]
# ##### Precision [Reference Link](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.precision_score.html#sklearn.metrics.precision_score)

# %%
from sklearn.metrics import precision_score
y_true = twenty_test_target
y_pred = predicted
precision_score(y_true, y_pred)
# Out:
# 0.74958632101489242

# %% [markdown]
# ##### Recall [Reference Link](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.recall_score.html)

# %%
from sklearn.metrics import recall_score
y_true = twenty_test_target
y_pred = predicted
recall_score(y_true, y_pred)
# Out:
# 0.8547169811320755

# %% [markdown]
# ##### Recall and precision of your classifier. [Reference Link](http://scikit-learn.org/stable/auto_examples/model_selection/plot_precision_recall.html)

# %%
#from sklearn.metrics import precision_recall_curve
#from sklearn.metrics import average_precision_score
#from sklearn.preprocessing import label_binarize
#X_train = X_train_lsi
#X_test = X_test_lsi
#y_train = twenty_train.target
#y_test = twenty_test.target
#y_score = clf.decision_function(X_test_lsi)
#y = label_binarize(twenty_train.target, classes=[0, 1])
# n_classes = y.shape
#print n_classes
# Compute Precision-Recall and plot curve
#precision = dict()
#recall = dict()
#average_precision = dict()
#for i in range(n_classes):
#precision, recall, _ = precision_recall_curve(y_test,y_score)    
#average_precision = average_precision_score(y_test, y_score)
#average_recall = average_recall_score(y_test, y_score)

#print precision
#print recall
#print average_precision
#print average_recall

# %% [markdown]
# ### Problem (f)

# %%
from sklearn.cross_validation import KFold
kf = KFold(n=len(twenty_train_target), n_folds=5, shuffle=False, random_state=None)
twenty_train_data = data_process(twenty_train)
twenty_test_data = data_process(twenty_test)
l = [[0]*7 for i in range(5)]
i=0
j=0
#la=[]
for train_index, test_index in kf:
    #print train_index
    #[ int(x / 4) for x in twenty_train.target]
    X_train_soft, X_test_soft = twenty_train_data[train_index], twenty_train_data[test_index]
    for k in [-3, -2, -1, 0, 1, 2, 3]:
        target_train = [ int(x / 4) for x in twenty_train.target[train_index]]
        target_test = [ int(x / 4) for x in twenty_train.target[test_index]]
        clf_soft = LinearSVC(C=10**k).fit(X_train_soft, target_train)
        #predicted_soft = clf.predict(X_test_soft_lsi)
        score = clf_soft.score(X_test_soft, target_test)
        #if k==1:
        #    print score
        #la.append(score)
        l[i][j]=score
        j=j+1
        #print 1
    i=i+1
    j=0

#print train_index
#twenty_train.data
#print (l)
#print la
# twenty_train_target[1]

# %%
#twenty_train.target[train_index]

# %%
average_s = list(map(lambda x: (x[0]+x[1]+x[2]+x[3]+x[4])/5, zip(l[0], l[1], l[2], l[3], l[4])))
#print average_s
value = max(average_s)
index=average_s.index(value)
#print index
penalty = [-3, -2, -1, 0, 1, 2, 3]
print ('The best penalty value is',10**penalty[index])
# Out:
# ('The best penalty value is', 100)

# %%
clf_soft_pre = LinearSVC(C=10**1).fit(twenty_train_data, twenty_train_target)
predicted_soft_pre = clf_soft_pre.predict(twenty_test_data)

s = clf_soft_pre.score(twenty_test_data, twenty_test_target)
print s
# Out:
# 0.805079365079

# %% [markdown]
# ##### Confusion matrix. [Reference Link](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html)

# %%
from sklearn.metrics import confusion_matrix
y_true = twenty_test_target
y_pred = predicted_soft_pre
print confusion_matrix(y_true, y_pred)
# Out:
# [[1170  390]
#  [ 224 1366]]

# %%
from sklearn.metrics import roc_curve, auc
y_score=clf_soft_pre.decision_function(twenty_test_data)
fpr, tpr, _ = roc_curve(twenty_test_target, y_score)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-eb5a687d60ed> in <module>()
#       4 roc_auc = auc(fpr, tpr)
#       5
# ----> 6 plt.figure()
#       7 plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
#       8 plt.plot([0, 1], [0, 1], 'k--')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ##### Accuracy [Reference Link](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html)

# %%
from sklearn.metrics import accuracy_score
y_true = twenty_test_target
y_pred = predicted_soft_pre
print accuracy_score(y_true, y_pred)

# %% [markdown]
# ##### Precision [Reference Link](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.precision_score.html#sklearn.metrics.precision_score)

# %%
from sklearn.metrics import precision_score
y_true = twenty_test_target
y_pred = predicted_soft_pre
precision_score(y_true, y_pred)
# Out:
# 0.83457782883400344

# %% [markdown]
# ##### Recall [Reference Link](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.recall_score.html)

# %%
from sklearn.metrics import recall_score
y_true = twenty_test_target
y_pred = predicted_soft_pre
recall_score(y_true, y_pred)
# Out:
# 0.9138364779874214

# %% [markdown]
# ##### Recall and precision of your classifier. [Reference Link](http://scikit-learn.org/stable/auto_examples/model_selection/plot_precision_recall.html)

# %%
# from sklearn.metrics import precision_recall_curve
# from sklearn.metrics import average_precision_score
# from sklearn.preprocessing import label_binarize
# X_train = X_train_lsi
# X_test = X_test_lsi
# y_train = twenty_train.target
# y_test = twenty_test.target
# y_score = clf_soft_pre.decision_function(X_test_lsi)
# y = label_binarize(twenty_train.target, classes=[0, 1])
# # n_classes = y.shape
# #print n_classes
# # Compute Precision-Recall and plot curve
# precision = dict()
# recall = dict()
# average_precision = dict()
# #for i in range(n_classes):
# precision, recall, _ = precision_recall_curve(y_test,y_score)    
# average_precision = average_precision_score(y_test, y_score)

# # print precision
# # print recall
# print average_precision

# %% [markdown]
# ### Problem (g)

# %% [markdown]
# ##### Naïve Bayes Algorithm [Reference Link](http://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.GaussianNB.html)

# %%
X_test_lsi = data_process(twenty_test)
predicted = clf_naive_bayes.predict(X_test_lsi)
print predicted.shape
score = clf_naive_bayes.score(X_test_lsi, twenty_test_target)
print score
# Out:
# (3150,)
# 0.663492063492

# %% [markdown]
# ##### ROC curve [Reference Link](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_curve.html)

# %%
from sklearn.metrics import roc_curve, auc
y_score=clf_naive_bayes.predict_proba(X_test_lsi)[:, 1]
fpr, tpr, _ = roc_curve(twenty_test_target, y_score)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-5bf5ffe27946> in <module>()
#       4 roc_auc = auc(fpr, tpr)
#       5
# ----> 6 plt.figure()
#       7 plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
#       8 plt.plot([0, 1], [0, 1], 'k--')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ##### Confusion matrix. [Reference Link](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html)

# %%
from sklearn.metrics import confusion_matrix
y_true = twenty_test_target
y_pred = predicted
print confusion_matrix(y_true, y_pred)

# %%
from sklearn.naive_bayes import GaussianNB
clf_naive_bayes = GaussianNB().fit(X_train_lsi, twenty_train_target)

# %% [markdown]
# ##### Accuracy [Reference Link](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html)

# %%
from sklearn.metrics import accuracy_score
y_true = twenty_test_target
y_pred = predicted
print accuracy_score(y_true, y_pred)
# Out:
# 0.663492063492

# %% [markdown]
# ##### Precision [Reference Link](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.precision_score.html#sklearn.metrics.precision_score)

# %%
from sklearn.metrics import precision_score
y_true = twenty_test_target
y_pred = predicted
precision_score(y_true, y_pred)
# Out:
# 0.73123909249563701

# %% [markdown]
# ##### Recall [Reference Link](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.recall_score.html)

# %%
from sklearn.metrics import recall_score
y_true = twenty_test_target
y_pred = predicted
recall_score(y_true, y_pred)
# Out:
# 0.5270440251572327

# %% [markdown]
# ##### Recall and precision of your classifier. [Reference Link](http://scikit-learn.org/stable/auto_examples/model_selection/plot_precision_recall.html)

# %%
# from sklearn.metrics import precision_recall_curve
# from sklearn.metrics import average_precision_score
# from sklearn.preprocessing import label_binarize
# X_train = X_train_lsi
# X_test = X_test_lsi
# y_train = twenty_train.target
# y_test = twenty_test.target
# y_score = clf_naive_bayes.predict_proba(X_test_lsi)[:, 1]
# y = label_binarize(twenty_train.target, classes=[0, 1])
# # n_classes = y.shape
# #print n_classes
# # Compute Precision-Recall and plot curve
# precision = dict()
# recall = dict()
# average_precision = dict()
# #for i in range(n_classes):
# precision, recall, _ = precision_recall_curve(y_test,y_score)    
# average_precision = average_precision_score(y_test, y_score)
# #average_recall = average_recall_score(y_test, y_score)

# # print precision
# #print recall
# #print average_precision

# %% [markdown]
# ### Problem (h)

# %% [markdown]
# ###### logistic regression [Reference Link](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html)

# %%
from sklearn.linear_model import LogisticRegression
clf_logistic_regression = LogisticRegression().fit(X_train_lsi, twenty_train_target)

# %%
X_test_lsi = data_process(twenty_test)
predicted = clf_logistic_regression.predict(X_test_lsi)
print predicted.shape
score = clf_logistic_regression.score(X_test_lsi, twenty_test_target)
print score
# Out:
# (3150,)
# 0.848571428571

# %% [markdown]
# ##### ROC curve [Reference Link](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_curve.html)

# %%
from sklearn.metrics import roc_curve, auc
y_score=clf_logistic_regression.predict_proba(X_test_lsi)[:, 1]
fpr, tpr, _ = roc_curve(twenty_test_target, y_score)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-11a55724f638> in <module>()
#       4 roc_auc = auc(fpr, tpr)
#       5
# ----> 6 plt.figure()
#       7 plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
#       8 plt.plot([0, 1], [0, 1], 'k--')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ##### Confusion matrix. [Reference Link](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html)

# %%
from sklearn.metrics import confusion_matrix
y_true = twenty_test_target
y_pred = predicted
print confusion_matrix(y_true, y_pred)
# Out:
# [[1220  340]
#  [ 137 1453]]

# %% [markdown]
# ##### Accuracy [Reference Link](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html)

# %%
from sklearn.metrics import accuracy_score
y_true = twenty_test_target
y_pred = predicted
print accuracy_score(y_true, y_pred)
# Out:
# 0.848571428571

# %% [markdown]
# ##### Precision [Reference Link](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.precision_score.html#sklearn.metrics.precision_score)

# %%
from sklearn.metrics import precision_score
y_true = twenty_test_target
y_pred = predicted
precision_score(y_true, y_pred)
# Out:
# 0.81037367540435024

# %% [markdown]
# ##### Recall [Reference Link](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.recall_score.html)

# %%
from sklearn.metrics import recall_score
y_true = twenty_test_target
y_pred = predicted
recall_score(y_true, y_pred)
# Out:
# 0.9138364779874214

# %% [markdown]
# ##### Recall and precision of your classifier. [Reference Link](http://scikit-learn.org/stable/auto_examples/model_selection/plot_precision_recall.html)

# %%
# from sklearn.metrics import precision_recall_curve
# from sklearn.metrics import average_precision_score
# from sklearn.preprocessing import label_binarize
# X_train = X_train_lsi
# X_test = X_test_lsi
# y_train = twenty_train.target
# y_test = twenty_test.target
# y_score = clf_logistic_regression.predict_proba(X_test_lsi)[:, 1]
# y = label_binarize(twenty_train.target, classes=[0, 1])
# # n_classes = y.shape
# #print n_classes
# # Compute Precision-Recall and plot curve
# precision = dict()
# recall = dict()
# average_precision = dict()
# #for i in range(n_classes):
# precision, recall, _ = precision_recall_curve(y_test,y_score)    
# average_precision = average_precision_score(y_test, y_score)

# # print precision
# # print recall
# print average_precision

# %% [markdown]
# ### Problem (i)

# %%
from sklearn.multiclass import OneVsRestClassifier
from sklearn.multiclass import OneVsOneClassifier
#from sklearn.svm import LinearSVC
categories_i = ['comp.sys.ibm.pc.hardware','comp.sys.mac.hardware','misc.forsale','soc.religion.christian']
twenty_train_i = fetch_20newsgroups(subset='train', categories=categories_i, shuffle=True, random_state=42, remove = ('headers', 'footers','quotes'))
twenty_test_i = fetch_20newsgroups(subset='test', categories=categories_i, shuffle=True, random_state=42, remove = ('headers', 'footers','quotes'))
twenty_train_lsi_i = data_process(twenty_train_i)
twenty_test_lsi_i = data_process(twenty_test_i)
#OneVsRestClassifier(LinearSVC(random_state=0)).fit(X, y).predict(X)
#OneVsOneClassifier(LinearSVC(random_state=0)).fit(X, y).predict(X)

# %%
#y = label_binarize(y, classes=[0, 1, 2])
#n_classes = y.shape[1]

# %%
y = twenty_train_i.target
y = label_binarize(y, classes=[0, 1, 2, 3])
n_classes = y.shape[1]
#print n_classes
y_test = twenty_test_i.target
y_test = label_binarize(y_test, classes=[0, 1, 2, 3])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-bee835dbbb76> in <module>()
#       1 y = twenty_train_i.target
# ----> 2 y = label_binarize(y, classes=[0, 1, 2, 3])
#       3 n_classes = y.shape[1]
#       4 #print n_classes
#       5 y_test = twenty_test_i.target
#
# NameError: name 'label_binarize' is not defined

# %%
#print twenty_train_i.target

# %% [markdown]
# ##### One VS Rest

# %%
fit_i = OneVsRestClassifier(LinearSVC()).fit(twenty_train_lsi_i, twenty_train_i.target)
predict_i = fit_i.predict(twenty_test_lsi_i)
score = fit_i.score(twenty_test_lsi_i, twenty_test_i.target)
#predict_score = fit_i.decision_function(twenty_test_lsi_i)
print score
# Out:
# 0.493290734824

# %%
fpr = dict()
tpr = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i],predict_score[:, i])

#print precision
#print recall

print precision_score(twenty_test_i.target, predict_i,average='weighted')  
print recall_score(twenty_test_i.target, predict_i,average='weighted') 
print accuracy_score(twenty_test_i.target, predict_i)
print confusion_matrix(twenty_test_i.target, predict_i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-7cdc9375e207> in <module>()
#       1 fpr = dict()
#       2 tpr = dict()
# ----> 3 for i in range(n_classes):
#       4     fpr[i], tpr[i], _ = roc_curve(y_test[:, i],predict_score[:, i])
#       5
#
# NameError: name 'n_classes' is not defined

# %% [markdown]
# ##### One VS One

# %%
fit_i = OneVsOneClassifier(LinearSVC()).fit(twenty_train_lsi_i, twenty_train_i.target)
predict_i = fit_i.predict(twenty_test_lsi_i)
score = fit_i.score(twenty_test_lsi_i, twenty_test_i.target)
#predict_score = fit_i.decision_function(twenty_test_lsi_i)
print score
# Out:
# 0.497763578275

# %%
fpr = dict()
tpr = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i],predict_score[:, i])

#print precision
#print recall
print precision_score(twenty_test_i.target, predict_i,average='weighted')  
print recall_score(twenty_test_i.target, predict_i, average='weighted') 
print accuracy_score(twenty_test_i.target, predict_i)
print confusion_matrix(twenty_test_i.target, predict_i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-35af475e1d78> in <module>()
#       1 fpr = dict()
#       2 tpr = dict()
# ----> 3 for i in range(n_classes):
#       4     fpr[i], tpr[i], _ = roc_curve(y_test[:, i],predict_score[:, i])
#       5
#
# NameError: name 'n_classes' is not defined

# %% [markdown]
# ##### Naive bayes

# %%
clf_naive_bayes = GaussianNB().fit(twenty_train_lsi_i, twenty_train_i.target)
predicted = clf_naive_bayes.predict(twenty_test_lsi_i)
print predicted.shape
score = clf_naive_bayes.score(twenty_test_lsi_i, twenty_test_i.target)
print score

print precision_score(twenty_test_i.target, predicted,average='weighted')  
print recall_score(twenty_test_i.target, predicted,average='weighted') 
print accuracy_score(twenty_test_i.target, predicted)
print confusion_matrix(twenty_test_i.target, predicted)
# Out:
# (1565,)
# 0.461341853035
# 0.455616902111
# 0.461341853035
# 0.461341853035
# [[123 184  51  34]
#  [120 118  79  68]
#  [ 92  70 171  57]
#  [ 46  23  19 310]]
