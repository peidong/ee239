# %% [markdown]
# ### Project 2
# This explanation are mainly from different sections of the scikit-learn tutorial on text classification available at http://scikit-learn.org.

# %% [markdown]
# ### Dataset
# 1. In this project we work with “20 Newsgroups” dataset. It is a collection of approximately 20,000 newsgroup documents, partitioned (nearly) evenly across 20 different newsgroups, each corresponding to a different topic.
# 2. To manually load the data, you need to run this python code.<a href="https://www.dropbox.com/s/5oek8qbsge1y64b/fetch_data.py?dl=0">link to fetch_data.py</a>
# 3. Easiest way to load the data is to use the built-in dataset loader for 20 newsgroups from scikit-learn package.

# %% [markdown]
# ### Problem (a)

# %%
from sklearn.datasets import fetch_20newsgroups
categories = ['comp.graphics','rec.autos']
twenty_train = fetch_20newsgroups(subset='train', categories=categories, shuffle=True, random_state=42)
twenty_test = fetch_20newsgroups(subset='test', categories=categories, shuffle=True, random_state=42)

# %%
from sklearn.feature_extraction.text import CountVectorizer
def get_Number(fileName):
    count_vect = CountVectorizer()
    categories = [fileName]
    comp_graphic_train = fetch_20newsgroups(subset='train', categories=categories)
    comp_graphics_number = count_vect.fit_transform(comp_graphic_train.data)
    #print("(number of documents, number of features) = (%s, %s) " % comp_graphics_number.shape)
    [r,v] = comp_graphics_number.shape
    return r

comp_graphics_number = get_Number('comp.graphics')
comp_os_mswindows_misc_number = get_Number('comp.os.ms-windows.misc')
comp_sys_ibm_pc_hardware_number = get_Number('comp.sys.ibm.pc.hardware')
comp_sys_mac_hardware_number = get_Number('comp.sys.mac.hardware')
rec_autos_number = get_Number('rec.autos')
rec_motorcycles_number = get_Number('rec.motorcycles')
rec_sport_baseball_number = get_Number('rec.sport.baseball')
rec_sport_hockey_number = get_Number('rec.sport.hockey')

# %%
Number_Computer_technology = comp_graphics_number+comp_os_mswindows_misc_number+comp_sys_ibm_pc_hardware_number+comp_sys_mac_hardware_number
Number_Recreational_activity = rec_autos_number+rec_motorcycles_number+rec_sport_baseball_number+rec_sport_hockey_number

print("Number of class is = %s" % Number_Computer_technology)
print("Number of class is = %s" % Number_Recreational_activity)

import numpy as np
import matplotlib.pyplot as plt

n_groups = 8

document_number = (comp_graphics_number, comp_os_mswindows_misc_number, comp_sys_ibm_pc_hardware_number, comp_sys_mac_hardware_number, rec_autos_number, rec_motorcycles_number, rec_sport_baseball_number, rec_sport_hockey_number)

# fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.4
# Out:
# Number of class is = 2343
# Number of class is = 2389

# %%
objects = ('graphics', 'misc', 'pc.Hardware', 'mac.hardware', 'autos', 'motorcycles','baseball','hocky')
y_pos = np.arange(len(objects))

# %matplotlib inline
plt.figure()
plt.bar(y_pos, document_number, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Numbers')
plt.title('The number of documents')
plt.show()

# %% [markdown]
# ### Problem (b)

# %%
from sklearn.feature_extraction import text
import string
#from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.datasets import fetch_20newsgroups
stop_words = text.ENGLISH_STOP_WORDS.union(string.punctuation)

# %%
twenty_train = fetch_20newsgroups(subset='train', shuffle=True, random_state=42, remove = ('headers', 'footers','quotes'))
twenty_test = fetch_20newsgroups(subset='test', shuffle=True, random_state=42, remove = ('headers', 'footers','quotes'))

# %% [markdown]
# The converse mapping from feature name to column index is stored in the vocabulary_ attribute of the vectorizer:

# %%
import nltk
from nltk.stem import WordNetLemmatizer
stemmer = WordNetLemmatizer()

# %%
import nltk
import re
import string
#import regex as re
# stopwords = nltk.corpus.stopwords.words('english')
# from nltk.stem.snowball import SnowballStemmer
# stemmer = SnowballStemmer("english")
from nltk.stem import WordNetLemmatizer
stemmer = WordNetLemmatizer()
def remove_punctuation(text):
    return re.sub(r'[^A-Za-z]', " ", text)
def tokenize_and_stem(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    
    tokens =[word for sent in nltk.sent_tokenize(remove_punctuation(text)) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]{2,}', token):
            filtered_tokens.append(token)
            
    stems = [stemmer.lemmatize(t) for t in filtered_tokens]
    print stems
    return stems

# %%
count_vect = TfidfVectorizer(tokenizer=tokenize_and_stem,min_df=1,stop_words= stop_words, token_pattern='[a-zA-Z]{2,}')
# count_vect = CountVectorizer(min_df=1, stop_words= stop_words, token_pattern='[a-zA-Z]{2,}')
# X_train_counts = count_vect.fit_transform(stemmed)
X_train_counts = count_vect.fit_transform(twenty_train.data)
print X_train_counts.shape
#X_train_counts
#print(X_train_counts[0,3949])
#0, 6035
#print count_vect.get_feature_names()
# Out:
# [u'wa', u'wondering', u'if', u'anyone', u'out', u'there', u'could', u'enlighten', u'me', u'on', u'this', u'car', u'saw', u'the', u'other', u'day', u'it', u'wa', u'door', u'sport', u'car', u'looked', u'to', u'be', u'from', u'the', u'late', u'early', u'it', u'wa', u'called', u'bricklin', u'the', u'door', u'were', u'really', u'small', u'in', u'addition', u'the', u'front', u'bumper', u'wa', u'separate', u'from', u'the', u'rest', u'of', u'the', u'body', u'this', u'is', u'all', u'know', u'if', u'anyone', u'can', u'tellme', u'model', u'name', u'engine', u'spec', u'year', u'of', u'production', u'where', u'this', u'car', u'is', u'made', u'history', u'or', u'whatever', u'info', u'you', u'have', u'on', u'this', u'funky', u'looking', u'car', u'please', u'mail']
# [u'fair', u'number', u'of', u'brave', u'soul', u'who', u'upgraded', u'their', u'si', u'clock', u'oscillator', u'have', u'shared', u'their', u'experience', u'for', u'this', u'poll', u'please', u'send', u'brief', u'message', u'detailing', u'your', u'experience', u'with', u'the', u'procedure', u'top', u'speed', u'attained', u'cpu', u'rated', u'speed', u'add', u'on', u'card', u'and', u'adapter', u'heat', u'sink', u'hour', u'of', u'usage', u'per', u'day', u'floppy', u'disk', u'functionality', u'with', u'and', u'floppy', u'are', u'especially', u'requested', u'will', u'be', u'summarizing', u'in', u'the', u'next', u'two', u'day', u'so', u'please', u'add', u'to', u'the', u'network', u'knowledge', u'base', u'if', u'you', u'have', u'done', u'the', u'clock', u'upgrade', u'and', u'haven', u'answered', u'this', u'poll', u'thanks']
# [u'well', u'folk', u'my', u'mac', u'plus', u'finally', u'gave', u'up', u'the', u'ghost', u'this', u'weekend', u'after', u'starting', u'life', u'a', u'way', u'back', u'in', u'sooo', u'in', u'the', u'market', u'for', u'new', u'machine', u'bit', u'sooner', u'than', u'intended', u'to', u'be', u'looking', u'into', u'picking', u'up', u'powerbook', u'or', u'maybe', u'and', u'have', u'bunch', u'of', u'question', u'that', u'hopefully', u'somebody', u'can', u'answer', u'doe', u'anybody', u'know', u'any', u'dirt', u'on', u'when', u'the', u'next', u'round', u'of', u'powerbook', u'introduction', u'are', u'expected', u'heard', u'the', u'wa', u'supposed', u'to', u'make', u'an', u'appearence', u'this', u'summer', u'but', u'haven', u'heard', u'anymore', u'on', u'it', u'and', u'since', u'don', u'have', u'access', u'to', u'macleak', u'wa', u'wondering', u'if', u'anybody', u'out', u'there', u'had', u'more', u'info', u'ha', u'anybody', u'heard', u'rumor', u'about', u'price', u'drop', u'to', u'the', u'powerbook', u'line', u'like', u'the', u'one', u'the', u'duo', u'just', u'went', u'through', u'recently', u'what', u'the', u'impression', u'of', u'the', u'display', u'on', u'the', u'could', u'probably', u'swing', u'if', u'got', u'the', u'mb', u'disk', u'rather', u'than', u'the', u'but', u'don', u'really', u'have', u'feel', u'for', u'how', u'much', u'better', u'the', u'display', u'is', u'yea', u'it', u'look', u'great', u'in', u'the', u'store', u'but', u'is', u'that', u'all', u'wow', u'or', u'is', u'it', u'really', u'that', u'good', u'could', u'solicit', u'some', u'opinion', u'of', u'people', u'who', u'use', u'the', u'and', u'day', u'to', u'day', u'on', u'if', u'it', u'worth', u'taking', u'the', u'disk', u'size', u'and', u'money', u'hit', u'to', u'get', u'the', u'active', u'display', u'realize', u'this', u'is', u'real', u'subjective', u'question', u'but', u've', u'only', u'played', u'around', u'with', u'the', u'machine', u'in', u'computer', u'store', u'breifly', u'and', u'figured', u'the', u'opinion', u'of', u'somebody', u'who', u'actually', u'us', u'the', u'machine', u'daily', u'might', u'prove', u'helpful', u'how', u'well', u'doe', u'hellcat', u'perform', u'thanks', u'bunch', u'in', u'advance', u'for', u'any', u'info', u'if', u'you', u'could', u'email', u'll', u'post', u'summary', u'news', u'reading', u'time', u'is', u'at', u'premium', u'with', u'final', u'just', u'around', u'the', u'corner', u'tom', u'willis', u'twillis', u'ecn', u'purdue', u'edu', u'purdue', u'electrical', u'engineering']
# [u'do', u'you', u'have', u'weitek', u'address', u'phone', u'number', u'like', u'to', u'get', u'some', u'information', u'about', u'this', u'chip']
# [u'from', u'article', u'owcb', u'world', u'std', u'com', u'by', u'tombaker', u'world', u'std', u'com', u'tom', u'baker', u'my', u'understanding', u'is', u'that', u'the', u'expected', u'error', u'are', u'basically', u'known', u'bug', u'in', u'the', u'warning', u'system', u'software', u'thing', u'are', u'checked', u'that', u'don', u'have', u'the', u'right', u'value', u'in', u'yet', u'because', u'they', u'aren', u'set', u'till', u'after', u'launch', u'and', u'suchlike', u'rather', u'than', u'fix', u'the', u'code', u'and', u'possibly', u'introduce', u'new', u'bug', u'they', u'just', u'tell', u'the', u'crew', u'ok', u'if', u'you', u'see', u'warning', u'no', u'before', u'liftoff', u'ignore', u'it']
# [u'of', u'course', u'the', u'term', u'must', u'be', u'rigidly', u'defined', u'in', u'any', u'bill', u'doubt', u'she', u'us', u'this', u'term', u'for', u'that', u'you', u'are', u'using', u'quote', u'allegedly', u'from', u'her', u'can', u'you', u'back', u'it', u'up', u'read', u'the', u'article', u'a', u'presenting', u'first', u'an', u'argument', u'about', u'weapon', u'of', u'mass', u'destruction', u'a', u'commonly', u'understood', u'and', u'then', u'switching', u'to', u'other', u'topic', u'the', u'first', u'point', u'evidently', u'wa', u'to', u'show', u'that', u'not', u'all', u'weapon', u'should', u'be', u'allowed', u'and', u'then', u'the', u'later', u'analysis', u'wa', u'given', u'this', u'understanding', u'to', u'consider', u'another', u'class']
# [u'there', u'were', u'few', u'people', u'who', u'responded', u'to', u'my', u'request', u'for', u'info', u'on', u'treatment', u'for', u'astrocytomas', u'through', u'email', u'whom', u'couldn', u'thank', u'directly', u'because', u'of', u'mail', u'bouncing', u'probs', u'sean', u'debra', u'and', u'sharon', u'so', u'thought', u'publicly', u'thank', u'everyone', u'thanks', u'sure', u'glad', u'accidentally', u'hit', u'rn', u'instead', u'of', u'rm', u'when', u'wa', u'trying', u'to', u'delete', u'file', u'last', u'september', u'hmmm', u'news', u'what', u'this']
# [u'all', u'this', u'show', u'is', u'that', u'you', u'don', u'know', u'much', u'about', u'scsi', u'scsi', u'with', u'scsi', u'controler', u'chip', u'range', u'is', u'indeed', u'mb', u'and', u'that', u'is', u'all', u'you', u'have', u'right', u'about', u'scsi', u'scsi', u'with', u'scsi', u'controller', u'chip', u'mb', u'with', u'mb', u'burst', u'bit', u'note', u'the', u'increase', u'in', u'speed', u'the', u'mac', u'quadra', u'us', u'this', u'version', u'of', u'scsi', u'so', u'it', u'doe', u'exist', u'some', u'pc', u'use', u'this', u'set', u'up', u'too', u'scsi', u'bit', u'scsi', u'mode', u'mb', u'with', u'mb', u'burst', u'scsi', u'bit', u'wide', u'or', u'fast', u'mode', u'mb', u'with', u'mb', u'burst', u'scsi', u'bit', u'wide', u'and', u'fast', u'mb', u'with', u'mb', u'burst', u'by', u'your', u'own', u'data', u'the', u'although', u'scsi', u'is', u'twice', u'a', u'fast', u'a', u'esdi', u'is', u'correct', u'with', u'scsi', u'controller', u'chip', u'scsi', u'can', u'reach', u'mb', u'which', u'is', u'indeed', u'faster', u'than', u'ide', u'of', u'is', u'all', u'these', u'scsi', u'fact', u'have', u'been', u'posted', u'to', u'this', u'newsgroup', u'in', u'my', u'mac', u'ibm', u'info', u'sheet', u'available', u'by', u'ftp', u'on', u'sumex', u'aim', u'stanford', u'edu', u'in', u'the', u'info', u'mac', u'report', u'a', u'mac', u'ibm', u'compare', u'version', u'txt', u'it', u'should', u'be', u'but', u'may', u'still', u'be', u'there', u'part', u'of', u'this', u'problem', u'is', u'both', u'mac', u'and', u'ibm', u'pc', u'are', u'inconsiant', u'about', u'what', u'scsi', u'is', u'which', u'though', u'it', u'is', u'well', u'documented', u'that', u'the', u'quadra', u'ha', u'scsi', u'chip', u'an', u'apple', u'salesperson', u'said', u'it', u'us', u'fast', u'scsi', u'chip', u'not', u'at', u'mb', u'mb', u'burst', u'it', u'doe', u'not', u'scsi', u'is', u'mb', u'maximum', u'synchronous', u'and', u'quadra', u'us', u'ansynchronous', u'scsi', u'which', u'is', u'slower', u'it', u'seems', u'that', u'mac', u'and', u'ibm', u'see', u'scsi', u'interface', u'and', u'think', u'scsi', u'when', u'it', u'maybe', u'scsi', u'interface', u'driven', u'in', u'the', u'machine', u'by', u'scsi', u'controller', u'chip', u'in', u'bit', u'mode', u'which', u'is', u'much', u'faster', u'then', u'true', u'scsi', u'can', u'go']
# [u'have', u'win', u'and', u'downloaded', u'several', u'icon', u'and', u'bmp', u'but', u'can', u'figure', u'out', u'how', u'to', u'change', u'the', u'wallpaper', u'or', u'use', u'the', u'icon', u'any', u'help', u'would', u'be', u'appreciated', u'thanx', u'brando']
# [u've', u'had', u'the', u'board', u'for', u'over', u'year', u'and', u'it', u'doe', u'work', u'with', u'diskdoubler', u'but', u'not', u'with', u'autodoubler', u'due', u'to', u'licensing', u'problem', u'with', u'stac', u'technology', u'the', u'owner', u'of', u'the', u'board', u'compression', u'technology', u'writing', u'this', u'from', u'memory', u've', u'lost', u'the', u'reference', u'please', u'correct', u'me', u'if', u'wrong', u'using', u'the', u'board', u've', u'had', u'problem', u'with', u'file', u'icon', u'being', u'lost', u'but', u'it', u'hard', u'to', u'say', u'whether', u'it', u'the', u'board', u'fault', u'or', u'something', u'else', u'however', u'if', u'decompress', u'the', u'troubled', u'file', u'and', u'recompress', u'it', u'without', u'the', u'board', u'the', u'icon', u'usually', u'reappears', u'because', u'of', u'the', u'above', u'mentioned', u'licensing', u'problem', u'the', u'freeware', u'expansion', u'utility', u'dd', u'expand', u'will', u'not', u'decompress', u'board', u'compressed', u'file', u'unless', u'you', u'have', u'the', u'board', u'installed', u'since', u'stac', u'ha', u'it', u'own', u'product', u'now', u'it', u'seems', u'unlikely', u'that', u'the', u'hole', u'in', u'autodoubler', u'diskdoubler', u'related', u'to', u'the', u'board', u'will', u'be', u'fixed', u'which', u'is', u'sad', u'and', u'make', u'me', u'very', u'reluctant', u'to', u'buy', u'stac', u'product', u'since', u'they', u're', u'being', u'so', u'stinky', u'but', u'hey', u'that', u'competition']
# [u'have', u'line', u'on', u'ducati', u'gts', u'model', u'with', u'on', u'the', u'clock', u'run', u'very', u'well', u'paint', u'is', u'the', u'bronze', u'brown', u'orange', u'faded', u'out', u'leak', u'bit', u'of', u'oil', u'and', u'pop', u'out', u'of', u'st', u'with', u'hard', u'accel', u'the', u'shop', u'will', u'fix', u'trans', u'and', u'oil', u'leak', u'they', u'sold', u'the', u'bike', u'to', u'the', u'and', u'only', u'owner', u'they', u'want', u'and', u'am', u'thinking', u'more', u'like', u'any', u'opinion', u'out', u'there', u'please', u'email', u'me', u'thanks', u'it', u'would', u'be', u'nice', u'stable', u'mate', u'to', u'the', u'beemer', u'then', u'll', u'get', u'jap', u'bike', u'and', u'call', u'myself', u'axis', u'motor', u'tuba', u'irwin', u'honk', u'therefore', u'am', u'computrac', u'richardson', u'tx', u'irwin', u'cmptrc', u'lonestar', u'org', u'dod']
# [u'yep', u'that', u'pretty', u'much', u'it', u'not', u'jew', u'but', u'understand', u'that', u'this', u'is', u'the', u'jewish', u'way', u'of', u'thinking', u'however', u'the', u'jew', u'believe', u'that', u'the', u'covenant', u'between', u'yhwh', u'and', u'the', u'patriarch', u'abraham', u'and', u'moses', u'in', u'this', u'case', u'establishes', u'moral', u'code', u'to', u'follow', u'for', u'mankind', u'even', u'the', u'jew', u'could', u'not', u'decide', u'where', u'the', u'boundary', u'fall', u'though', u'a', u'understand', u'it', u'the', u'sadducee', u'believed', u'that', u'the', u'torah', u'wa', u'all', u'that', u'wa', u'required', u'whereas', u'the', u'pharisee', u'the', u'ancestor', u'of', u'modern', u'judaism', u'believed', u'that', u'the', u'torah', u'wa', u'available', u'for', u'interpretation', u'to', u'lead', u'to', u'an', u'understanding', u'of', u'the', u'required', u'morality', u'in', u'all', u'it', u'nuance', u'talmud', u'the', u'essence', u'of', u'all', u'of', u'this', u'is', u'that', u'biblical', u'morality', u'is', u'an', u'interface', u'between', u'man', u'and', u'yhwh', u'for', u'jew', u'or', u'christian', u'and', u'doe', u'not', u'necessarily', u'indicate', u'anything', u'about', u'yhwh', u'outside', u'of', u'that', u'relationship', u'although', u'one', u'can', u'speculate', u'the', u'trouble', u'with', u'all', u'of', u'this', u'is', u'that', u'we', u'don', u'really', u'know', u'what', u'the', u'created', u'in', u'his', u'image', u'mean', u've', u'heard', u'number', u'of', u'different', u'opinion', u'on', u'this', u'and', u'have', u'still', u'not', u'come', u'to', u'any', u'conclusion', u'this', u'rather', u'upset', u'the', u'apple', u'cart', u'if', u'one', u'want', u'to', u'base', u'life', u'script', u'on', u'this', u'shaky', u'foundation', u'to', u'mix', u'metaphor', u'unashamedly', u'a', u'to', u'living', u'by', u'christ', u'example', u'we', u'know', u'very', u'little', u'about', u'jesus', u'a', u'person', u'we', u'only', u'have', u'his', u'recorded', u'utterance', u'in', u'set', u'of', u'narrative', u'by', u'his', u'follower', u'and', u'some', u'very', u'small', u'reference', u'from', u'comtemporary', u'historian', u'revelation', u'aside', u'one', u'can', u'only', u'know', u'christ', u'second', u'hand', u'or', u'worse', u'this', u'is', u'not', u'an', u'attempt', u'to', u'debunk', u'christianity', u'although', u'it', u'may', u'seem', u'that', u'way', u'initially', u'the', u'point', u'trying', u'to', u'make', u'is', u'that', u'we', u'only', u'really', u'have', u'the', u'bible', u'to', u'interpret', u'and', u'that', u'interpretation', u'is', u'by', u'humanity', u'guess', u'this', u'is', u'where', u'faith', u'or', u'relevation', u'come', u'in', u'with', u'all', u'it', u'inherent', u'subjectiveness', u'no', u'there', u'may', u'be', u'an', u'absolute', u'moral', u'code', u'there', u'are', u'undoubtably', u'multiple', u'moral', u'code', u'the', u'multiple', u'moral', u'code', u'may', u'be', u'founded', u'in', u'the', u'absolute', u'moral', u'code', u'a', u'an', u'example', u'parent', u'may', u'tell', u'child', u'never', u'to', u'swear', u'and', u'the', u'child', u'may', u'assume', u'that', u'the', u'parent', u'never', u'swears', u'simply', u'because', u'the', u'parent', u'ha', u'told', u'the', u'child', u'that', u'it', u'is', u'wrong', u'now', u'the', u'parent', u'may', u'swear', u'like', u'trooper', u'in', u'the', u'pub', u'or', u'bar', u'where', u'there', u'are', u'no', u'child', u'the', u'wrongness', u'here', u'is', u'if', u'the', u'child', u'disobeys', u'the', u'parent', u'the', u'parent', u'may', u'feel', u'that', u'it', u'is', u'inappropriate', u'to', u'swear', u'in', u'front', u'of', u'child', u'but', u'may', u'be', u'quite', u'happy', u'to', u'swear', u'in', u'front', u'of', u'animal', u'the', u'analogy', u'doe', u'not', u'quite', u'hold', u'water', u'because', u'the', u'child', u'know', u'that', u'he', u'is', u'of', u'the', u'same', u'type', u'a', u'the', u'parent', u'and', u'may', u'be', u'parent', u ...
# []
# [u'description', u'of', u'external', u'tank', u'option', u'for', u'ssf', u'redesign', u'deleted', u'yo', u'ken', u'let', u'keep', u'on', u'top', u'of', u'thing', u'both', u'the', u'external', u'tank', u'and', u'wingless', u'orbiter', u'option', u'have', u'been', u'deleted', u'from', u'the', u'ssf', u'redesign', u'option', u'list', u'today', u'edition', u'of', u'the', u'new', u'york', u'time', u'report', u'that', u'connor', u'told', u'the', u'panel', u'that', u'some', u'redesign', u'proposal', u'have', u'been', u'dropped', u'such', u'a', u'using', u'the', u'giant', u'external', u'fuel', u'tank', u'used', u'in', u'launching', u'space', u'shuttle', u'and', u'building', u'station', u'around', u'an', u'existing', u'space', u'shuttle', u'with', u'it', u'wing', u'and', u'tail', u'removed', u'currently', u'there', u'are', u'three', u'option', u'being', u'considered', u'a', u'presented', u'to', u'the', u'advisory', u'panel', u'meeting', u'yesterday', u'and', u'a', u'reported', u'in', u'today', u'time', u'option', u'low', u'cost', u'modular', u'approach', u'this', u'option', u'is', u'being', u'studied', u'by', u'team', u'from', u'msfc', u'a', u'an', u'aside', u'there', u'are', u'ssf', u'redesign', u'team', u'at', u'msfc', u'jsc', u'and', u'larc', u'supporting', u'the', u'srt', u'station', u'redesign', u'team', u'in', u'crystal', u'city', u'both', u'lerc', u'and', u'reston', u'folk', u'are', u'also', u'on', u'site', u'at', u'these', u'location', u'helping', u'the', u'respective', u'team', u'with', u'their', u'redesign', u'activity', u'key', u'feature', u'of', u'this', u'option', u'are', u'us', u'bus', u'modular', u'bus', u'developed', u'by', u'lockheed', u'that', u'qualified', u'for', u'sts', u'and', u'elv', u'the', u'bus', u'provides', u'propulsion', u'gn', u'communication', u'data', u'management', u'lockheed', u'developed', u'this', u'for', u'the', u'air', u'force', u'power', u'station', u'capability', u'is', u'obtained', u'in', u'shuttle', u'flight', u'ssf', u'solar', u'array', u'are', u'used', u'to', u'provide', u'kw', u'of', u'power', u'the', u'vehicle', u'fly', u'in', u'an', u'arrow', u'mode', u'to', u'optimize', u'the', u'microgravity', u'environment', u'shuttle', u'spacelab', u'mission', u'would', u'utilize', u'the', u'vehilce', u'a', u'power', u'source', u'for', u'day', u'mission', u'human', u'tended', u'capability', u'a', u'opposed', u'to', u'the', u'old', u'ssf', u'sexist', u'term', u'of', u'man', u'tended', u'capability', u'is', u'achieved', u'by', u'the', u'addition', u'of', u'the', u'u', u'common', u'module', u'this', u'is', u'modified', u'version', u'of', u'the', u'existing', u'ssf', u'lab', u'module', u'docking', u'port', u'are', u'added', u'for', u'the', u'international', u'partner', u'lab', u'taking', u'the', u'place', u'of', u'the', u'node', u'on', u'ssf', u'the', u'shuttle', u'can', u'be', u'docked', u'to', u'the', u'station', u'for', u'day', u'mission', u'the', u'orbiter', u'would', u'provide', u'crew', u'habitability', u'eva', u'capability', u'international', u'human', u'tended', u'add', u'the', u'nasda', u'esa', u'module', u'and', u'add', u'another', u'kw', u'of', u'power', u'permanent', u'human', u'presence', u'capability', u'add', u'rd', u'power', u'module', u'the', u'habitation', u'module', u'and', u'an', u'acrv', u'assured', u'crew', u'return', u'vehicle', u'option', u'space', u'station', u'freedom', u'derived', u'the', u'option', u'team', u'is', u'based', u'at', u'larc', u'and', u'is', u'lead', u'by', u'mike', u'griffin', u'this', u'option', u'look', u'alot', u'like', u'the', u'existing', u'ssf', u'design', u'which', u'we', u'have', u'all', u'come', u'to', u'know', u'and', u'love', u'this', u'option', u'assumes', u'lightweight', u'external', u'tank', u'is', u'available', u'for', u'use', u'on', u'all', u'ssf', u'assembly', u'flight', u'so', u'doe', u'option', u'also', u'the', u'number', u'of', u'flight', u'is', u'computed', u'for', u'inclination', u'orbit', u'for', u'both', u'option', u'and', u'the', u'build',  ...
# [u'reduced', u'price', u'have', u'list', u'of', u'thing', u'forsale', u'on', u'behalf', u'of', u'my', u'brother', u'who', u'moving', u'moved', u'already', u'offer', u'black', u'and', u'decker', u'duster', u'plus', u'portable', u'hand', u'vaccum', u'purchased', u'for', u'sr', u'dual', u'cassette', u'portable', u'player', u'am', u'fm', u'band', u'graphic', u'equalizer', u'high', u'speed', u'dubing', u'duo', u'tape', u'tape', u'deck', u'seems', u'to', u'have', u'lost', u'treble', u'sound', u'but', u'bet', u'it', u'fixable', u'purchased', u'for', u'monolux', u'zoom', u'microscope', u'up', u'to', u'magnification', u'made', u'in', u'japan', u'includes', u'case', u'and', u'accessory', u'purchased', u'for', u'sunbeam', u'hair', u'dryer', u'the', u'dryer', u'you', u'put', u'your', u'head', u'under', u'into', u'you', u'know', u'the', u'one', u'you', u'see', u'in', u'the', u'salon', u'don', u'ask', u'me', u'why', u'my', u'bro', u'had', u'it', u'purchased', u'for', u'everylast', u'speed', u'bag', u'all', u'leather', u'brand', u'new', u'never', u'used', u'osterizer', u'pusle', u'matic', u'blender', u'with', u'speed', u'and', u'cookbook', u'year', u'old', u'purchased', u'for', u'binolux', u'binoculars', u'extra', u'wide', u'angle', u'ft', u'at', u'yds', u'with', u'case', u'very', u'new', u'proctor', u'and', u'silex', u'spray', u'steam', u'and', u'dry', u'iron', u'very', u'new', u'any', u'question', u'contact', u'me', u'thru', u'mail', u'and', u'will', u'reply', u'expeditously', u'and', u'always', u'are', u'not', u'included', u'so', u'please', u'consider', u'this', u'and', u'lastly', u'very', u'reasonable', u'very', u'reasonable']
# [u'don', u'be', u'so', u'sure', u'look', u'what', u'happened', u'to', u'japanese', u'citizen', u'in', u'the', u'u', u'during', u'world', u'war', u'ii', u'if', u'you', u're', u'prepared', u'to', u'say', u'let', u'round', u'these', u'people', u'up', u'and', u'stick', u'them', u'in', u'concentration', u'camp', u'without', u'trial', u'it', u'only', u'short', u'step', u'to', u'gassing', u'them', u'without', u'trial', u'after', u'all', u'it', u'seems', u'that', u'the', u'nazi', u'originally', u'only', u'intended', u'to', u'imprison', u'the', u'jew', u'the', u'final', u'solution', u'wa', u'dreamt', u'up', u'partly', u'because', u'they', u'couldn', u'afford', u'to', u'run', u'the', u'camp', u'because', u'of', u'the', u'devastation', u'caused', u'by', u'goering', u'total', u'war', u'those', u'who', u'weren', u'gassed', u'generally', u'died', u'of', u'malnutrition', u'or', u'disease']
# [u'certainly', u'do', u'use', u'it', u'whenever', u'have', u'to', u'do', u'tiff', u'and', u'it', u'usually', u'work', u'very', u'well', u'that', u'not', u'my', u'point', u'philosophically', u'opposed', u'to', u'it', u'because', u'of', u'it', u'complexity', u'this', u'complexity', u'ha', u'led', u'to', u'some', u'program', u'poor', u'tiff', u'writer', u'making', u'some', u'very', u'bizarre', u'file', u'other', u'program', u'inability', u'to', u'load', u'tiff', u'image', u'though', u'they', u'll', u'save', u'them', u'of', u'course', u'and', u'general', u'inability', u'to', u'interchange', u'image', u'between', u'different', u'environment', u'despite', u'the', u'fact', u'they', u'all', u'think', u'they', u'understand', u'tiff', u'a', u'the', u'saying', u'go', u'it', u'not', u'me', u'worried', u'about', u'it', u'all', u'the', u'abuse', u'of', u'tiff', u'over', u'the', u'year', u'and', u'chalk', u'it', u'all', u'up', u'to', u'the', u'immense', u'and', u'unnecessary', u'complexity', u'of', u'the', u'format', u'in', u'the', u'word', u'of', u'the', u'tiff', u'spec', u'appendix', u'page', u'capitalized', u'emphasis', u'mine', u'the', u'only', u'problem', u'with', u'this', u'sort', u'of', u'success', u'is', u'that', u'tiff', u'wa', u'designed', u'to', u'be', u'powerful', u'and', u'flexible', u'at', u'the', u'expense', u'of', u'simplicity', u'it', u'take', u'fair', u'amount', u'of', u'effort', u'to', u'handle', u'all', u'the', u'option', u'currently', u'defined', u'in', u'this', u'specification', u'probably', u'no', u'application', u'doe', u'complete', u'job', u'and', u'that', u'is', u'currently', u'the', u'only', u'way', u'you', u'can', u'be', u'sure', u'that', u'you', u'will', u'be', u'able', u'to', u'import', u'any', u'tiff', u'image', u'since', u'there', u'are', u'so', u'many', u'image', u'generating', u'application', u'out', u'there', u'now', u'if', u'program', u'or', u'worse', u'all', u'application', u'can', u'read', u'every', u'tiff', u'image', u'that', u'mean', u'there', u'are', u'some', u'it', u'won', u'some', u'that', u'might', u'have', u'to', u'deal', u'with', u'why', u'would', u'want', u'my', u'image', u'to', u'be', u'trapped', u'in', u'that', u'format', u'don', u'and', u'neither', u'should', u'anyone', u'who', u'agrees', u'with', u'my', u'reasoning', u'not', u'that', u'anyone', u'doe', u'of', u'course']
# [u'recently', u'posted', u'an', u'article', u'asking', u'what', u'kind', u'of', u'rate', u'single', u'male', u'driver', u'under', u'yr', u'old', u'were', u'paying', u'on', u'performance', u'car', u'here', u'summary', u'of', u'the', u'reply', u'received', u'not', u'under', u'anymore', u'but', u'is', u'close', u'enough', u'dodge', u'stealth', u'rt', u'twin', u'turbo', u'hp', u'model', u'no', u'ticket', u'no', u'accident', u'own', u'house', u'have', u'taken', u'defensive', u'driving', u'airbag', u'ab', u'security', u'alarm', u'single', u'year', u'decut', u'state', u'farm', u'insurance', u'this', u'includes', u'the', u'additional', u'for', u'the', u'umbrella', u'policy', u'over', u'my', u'car', u'and', u'house', u'the', u'base', u'policy', u'is', u'the', u'standard', u'policy', u'required', u'in', u'de', u'after', u'nd', u'defensive', u'driving', u'course', u'it', u'will', u'be', u'le', u'bought', u'the', u'car', u'in', u'september', u'the', u'company', u'wa', u'with', u'never', u'had', u'and', u'accident', u'or', u'ticket', u'in', u'year', u'quoted', u'me', u'hope', u'this', u'help', u'steve', u'flynn', u'university', u'of', u'delaware', u'kevin', u'hope', u'remembered', u'your', u'name', u'correctly', u'you', u'asked', u'about', u'insurance', u'for', u'performance', u'car', u'well', u'last', u'year', u'wa', u'in', u'similar', u'situation', u'before', u'bought', u'my', u'car', u'and', u'made', u'the', u'same', u'inquiry', u'a', u'you', u'age', u'then', u'and', u'now', u'car', u'eagle', u'talon', u'tsi', u'awd', u'driving', u'record', u'clean', u'state', u'illinois', u'cost', u'mo', u'turn', u'in', u'may', u'and', u'the', u'insurance', u'go', u'down', u'to', u'mo', u'also', u'single', u'and', u'that', u'incurs', u'higher', u'rate', u'with', u'my', u'company', u've', u'got', u'couple', u'other', u'friend', u'awds', u'and', u'they', u'pay', u'more', u'than', u'do', u'different', u'in', u'company', u'also', u'so', u'maybe', u'just', u'lucky', u'hope', u'the', u'info', u'help', u'dan', u'dans', u'jdc', u'g', u'mot', u'com', u'motorola', u'cellular', u'subscriber', u'group', u'usa', u'cc', u'live', u'in', u'norman', u'oklahoma', u'drive', u'an', u'thunderbird', u'sc', u'have', u'never', u'made', u'claim', u'against', u'my', u'insurance', u'though', u'have', u'been', u'hit', u'several', u'time', u'by', u'negligent', u'driver', u'who', u'couldn', u'see', u'stop', u'sign', u'or', u'were', u'fiddling', u'with', u'their', u'radio', u'and', u'have', u'had', u'three', u'moving', u'violation', u'in', u'the', u'last', u'month', u'one', u'for', u'going', u'in', u'one', u'for', u'failure', u'to', u'clear', u'an', u'intersection', u'still', u'say', u'the', u'damn', u'light', u'wa', u'yellow', u'and', u'one', u'for', u'going', u'in', u'which', u'didn', u'go', u'on', u'my', u'record', u'my', u'rate', u'from', u'state', u'farm', u'with', u'passive', u'restraint', u'deduction', u'on', u'liability', u'deductible', u'comprehensive', u'and', u'deductible', u'collision', u'are', u'roughly', u'year', u'wa', u'paying', u'just', u'over', u'year', u'for', u'escort', u'lx', u'james', u'james', u'callison', u'microcomputer', u'coordinator', u'of', u'oklahoma', u'law', u'center', u'callison', u'uokmax', u'ecn', u'uoknor', u'edu', u'callison', u'aardvark', u'ucs', u'uoknor', u'edu', u'disclaimer', u'not', u'an', u'engineer', u'but', u'play', u'one', u'at', u'work', u'the', u'forecast', u'call', u'for', u'thunder', u'bird', u'sc', u'it', u'hell', u'of', u'thing', u'killing', u'man', u'you', u'take', u'away', u'all', u'he', u'ha', u'and', u'all', u'he', u'ever', u'gon', u'na', u'have', u'will', u'munny', u'unforgiven', u'am', u'beyond', u'the', u'under', u'age', u'group', u'but', u'have', u'an', u'experience', u'few', u'year', u'ago', u'that', u'might', u'be', u'interesting', u'to', u'you', u'owned', u'toyota', u'celica', u'gt', u'decided', u'to', u'buy', u'myself', u'gift', u'more', u'exotic', u'car', u'front', u'runner', u'included', u'the', u'toyota', u'supra',  ...
# [u'would', u'like', u'to', u'be', u'able', u'to', u'amplify', u'voltage', u'signal', u'which', u'is', u'output', u'from', u'thermocouple', u'preferably', u'by', u'factor', u'of', u'or', u'so', u'that', u'the', u'resulting', u'voltage', u'can', u'be', u'fed', u'more', u'easily', u'into', u'personal', u'computer', u'based', u'adc', u'data', u'acquisition', u'card', u'might', u'anyone', u'be', u'able', u'to', u'point', u'me', u'to', u'reference', u'to', u'such', u'circuit', u'have', u'seen', u'simple', u'amplifier', u'circuit', u'before', u'but', u'am', u'not', u'sure', u'how', u'well', u'they', u'work', u'in', u'practice', u'in', u'this', u'case', u'like', u'something', u'which', u'will', u'amplify', u'sufficiently', u'nicely', u'to', u'be', u'used', u'for', u'thermocouple', u'say', u'few', u'degree', u'accuracy', u'or', u'better']
# [u'question', u'what', u'is', u'the', u'exact', u'entry', u'parameter', u'and', u'syntax', u'please', u'in', u'the', u'terminal', u'configuration', u'file', u'loaded', u'when', u'the', u'terminal', u'boot', u'to', u'add', u'another', u'system', u'to', u'the', u'tcp', u'ip', u'access', u'control', u'list', u'background', u'have', u'two', u'unix', u'system', u'an', u'at', u'running', u'and', u'mit', u'and', u'sun', u's', u'without', u'any', u'want', u'to', u'have', u'window', u'to', u'the', u'sun', u'and', u'the', u'on', u'the', u'ncd', u'terminal', u'at', u'the', u'same', u'time', u'can', u'do', u'this', u'if', u'manually', u'set', u'the', u'network', u'parameter', u'tcp', u'ip', u'access', u'control', u'list', u'to', u'off', u'then', u'login', u'to', u'my', u'telnet', u'session', u'not', u'great', u've', u'tried', u'to', u'get', u'xhost', u'to', u'work', u'and', u'failed', u'either', u'my', u'syntax', u'is', u'wrong', u'or', u'the', u'implementation', u'is', u'bogus', u'am', u'trying', u'to', u'edit', u'the', u'ncd', u'configuration', u'file', u'that', u'is', u'loaded', u'when', u'the', u'ncd', u'boot', u'no', u'matter', u'what', u'entry', u'add', u'or', u'edit', u'the', u'ncd', u'still', u'boot', u'with', u'the', u'tcp', u'ip', u'access', u'control', u'list', u'containing', u'only', u'the', u'my', u'manual', u'are', u'worthless', u'so', u'any', u'help', u'would', u'be', u'most', u'appreciated', u'thanks']
# [u'these', u'don', u'seem', u'like', u'little', u'thing', u'to', u'me', u'at', u'least', u'they', u'are', u'order', u'worse', u'than', u'the', u'motto', u'do', u'you', u'think', u'that', u'the', u'motto', u'is', u'little', u'thing', u'that', u'will', u'lead', u'to', u'worse', u'thing']
# [u'think', u'that', u'mike', u'foligno', u'wa', u'the', u'captain', u'of', u'the', u'sabre', u'when', u'he', u'got', u'traded', u'to', u'the', u'leaf', u'also', u'wasn', u'rick', u'vaive', u'the', u'captain', u'of', u'the', u'leaf', u'when', u'he', u'got', u'traded', u'to', u'chicago', u'with', u'steve', u'thomas', u'for', u'ed', u'olcyzk', u'and', u'someone', u'speaking', u'of', u'the', u'leaf', u'believe', u'that', u'darryl', u'sittler', u'wa', u'their', u'captain', u'he', u'torn', u'the', u'off', u'his', u'jersey', u'but', u'think', u'he', u're', u'claimed', u'the', u'captaincy', u'later', u'on', u'when', u'he', u'wa', u'traded', u'to', u'the', u'flyer', u'oh', u'yeah', u'of', u'course', u'gretzky', u'wa', u'the', u'captain', u'of', u'the', u'oiler', u'before', u'he', u'wa', u'traded', u'wasn', u'he']
# [u'the', u'catalog', u'of', u'personal', u'computing', u'tool', u'for', u'engineer', u'and', u'scien', u'tists', u'list', u'hardware', u'card', u'and', u'application', u'software', u'package', u'for', u'pc', u'xt', u'at', u'p', u'class', u'machine', u'focus', u'is', u'on', u'engineering', u'and', u'scien', u'tific', u'application', u'of', u'pc', u'such', u'a', u'data', u'acquisition', u'control', u'design', u'automation', u'and', u'data', u'analysis', u'and', u'presentation', u'if', u'you', u'would', u'like', u'free', u'copy', u'reply', u'with', u'your', u'postal', u'mailing', u'address', u'have', u'copy', u'of', u'this', u'catalog', u'in', u'front', u'of', u'me', u'a', u'write', u'this', u'it', u'doe', u'have', u'ton', u'of', u'qool', u'stuff', u'in', u'it', u'my', u'impression', u'is', u'that', u'they', u'try', u'not', u'to', u'send', u'it', u'out', u'to', u'browser', u'it', u'appears', u'that', u'if', u'your', u'not', u'buyer', u'or', u'an', u'engineer', u'they', u'do', u'not', u'want', u'to', u'waste', u'catalog', u'on', u'you', u'when', u'you', u'get', u'catalog', u'there', u'vip', u'code', u'you', u'have', u'to', u'give', u'them', u'to', u'ensure', u'your', u'continued', u'subscription', u'anyway', u'if', u'you', u'want', u'to', u'get', u'in', u'touch', u'with', u'them', u'the', u'company', u'is', u'personal', u'computing', u'tool', u'division', u'street', u'campbell', u'ca', u'they', u'also', u'have', u'fax', u'and', u'toll', u'free', u'for', u'ordering', u'and', u'tech', u'support']
# [u'the', u'control', u'box', u'of', u'the', u'window', u'itself', u'upper', u'left', u'corner', u'of', u'the', u'window', u'single', u'click', u'am', u'being', u'too', u'simplistic', u'ha', u'font', u'option', u'the', u'is', u'about', u'the', u'biggest', u'one', u'can', u'use', u'without', u'the', u'character', u'turning', u'funky']
# [u'don', u'know', u'about', u'the', u'specific', u'problem', u'mentioned', u'in', u'your', u'message', u'but', u'definitely', u'had', u'scsi', u'problem', u'between', u'my', u'and', u'my', u'venerable', u'jasmine', u'megadrive', u'cartridge', u'drive', u'my', u'solution', u'wa', u'to', u'get', u'silverlining', u'none', u'of', u'the', u'loop', u'that', u'involved', u'blind', u'writes', u'worked', u'to', u'the', u'drive', u'in', u'fact', u'the', u'only', u'loop', u'that', u'worked', u'wa', u'the', u'macintosh', u'software', u'loop', u'whatever', u'that', u'mean']
# [u'hello', u'am', u'looking', u'to', u'add', u'voice', u'input', u'capability', u'to', u'user', u'interface', u'am', u'developing', u'on', u'an', u'hp', u'unix', u'workstation', u'would', u'greatly', u'appreciate', u'information', u'anyone', u'would', u'care', u'to', u'offer', u'about', u'voice', u'input', u'system', u'that', u'are', u'easily', u'accessible', u'from', u'the', u'unix', u'environment', u'the', u'name', u'or', u'adresses', u'of', u'applicable', u'vendor', u'a', u'well', u'a', u'any', u'experience', u'you', u'have', u'had', u'with', u'specific', u'system', u'would', u'be', u'very', u'helpful', u'please', u'respond', u'via', u'email', u'will', u'post', u'summary', u'if', u'there', u'is', u'sufficient', u'interest', u'thanks', u'ken', u'have', u'found', u'several', u'impressive', u'system', u'for', u'ibm', u'pc', u'but', u'would', u'like', u'to', u'avoid', u'the', u'hassle', u'of', u'purchasing', u'and', u'maintaining', u'separate', u'pc', u'if', u'at', u'all', u'possible', u'ken', u'hinckley', u'kph', u'virginia', u'edu', u'university', u'of', u'virginia', u'neurosurgical', u'visualization', u'laboratory']
# [u'actually', u'fossil', u'fuel', u'plant', u'run', u'hotter', u'than', u'the', u'usual', u'boiling', u'water', u'reactor', u'nuclear', u'plant', u'there', u'gripe', u'in', u'the', u'industry', u'that', u'nuclear', u'power', u'us', u'vintage', u'steam', u'technology', u'so', u'it', u'more', u'important', u'in', u'nuclear', u'plant', u'to', u'get', u'the', u'cold', u'end', u'of', u'the', u'system', u'a', u'cold', u'a', u'possible', u'hence', u'big', u'cooling', u'tower', u'oil', u'and', u'gas', u'fired', u'steam', u'plant', u'also', u'have', u'condenser', u'but', u'they', u'usually', u'are', u'sized', u'to', u'get', u'the', u'steam', u'back', u'into', u'hot', u'water', u'not', u'most', u'of', u'the', u'way', u'down', u'to', u'ambient', u'some', u'plant', u'do', u'cool', u'the', u'condenser', u'with', u'water', u'rather', u'than', u'air', u'a', u'one', u'canadian', u'official', u'asked', u'about', u'thermal', u'pollution', u'de', u'icing', u'river', u'said', u'up', u'here', u'we', u'view', u'heat', u'a', u'resource', u'everybody', u'run', u'closed', u'cycle', u'boiler', u'the', u'water', u'used', u'is', u'purified', u'of', u'solid', u'which', u'otherwise', u'crud', u'up', u'the', u'boiler', u'plumbing', u'when', u'the', u'water', u'boil', u'purifying', u'water', u'for', u'boiler', u'use', u'is', u'bigger', u'job', u'than', u'cooling', u'it', u'so', u'the', u'boiler', u'water', u'is', u'recycled']
# [u'doug', u'robert', u'ken', u'hill', u'for', u'nl', u'mvp', u'let', u'go', u'spos']
# [u'yes', u'am', u'adamantly', u'an', u'environmentalist', u'will', u'not', u'use', u'styrofoam', u'table', u'service', u'please', u'keep', u'that', u'in', u'mind', u'a', u'you', u'read', u'this', u'post', u'do', u'not', u'wish', u'to', u'attack', u'environmentalism', u'half', u'truth', u'is', u'at', u'least', u'a', u'dangerous', u'a', u'complete', u'lie', u'complete', u'lie', u'will', u'rarely', u'be', u'readily', u'accepted', u'while', u'half', u'truth', u'the', u'lie', u'subtly', u'hidden', u'is', u'more', u'powerfully', u'offered', u'by', u'one', u'who', u'masquerade', u'a', u'an', u'angel', u'of', u'light', u'satan', u'ha', u'for', u'some', u'people', u'loosened', u'the', u'grip', u'on', u'treating', u'the', u'earth', u'a', u'something', u'other', u'than', u'god', u'intricate', u'handiwork', u'something', u'other', u'than', u'that', u'on', u'which', u'the', u'health', u'of', u'future', u'generation', u'is', u'based', u'it', u'is', u'being', u'treated', u'with', u'respect', u'you', u'think', u'he', u'going', u'to', u'happily', u'leave', u'it', u'at', u'that', u'no', u'when', u'one', u'error', u'is', u'rejected', u'it', u'is', u'his', u'style', u'to', u'push', u'people', u'to', u'the', u'opposite', u'error', u'therefore', u'the', u'earth', u'is', u'not', u'god', u'intricate', u'handiwork', u'not', u'because', u'it', u'is', u'rubbish', u'but', u'because', u'it', u'is', u'god', u'mother', u'earth', u'is', u'the', u'one', u'you', u'are', u'to', u'primarily', u'love', u'and', u'serve', u'see', u'two', u'facet', u'of', u'response', u'to', u'it', u'care', u'for', u'the', u'environment', u'treat', u'it', u'with', u'proper', u'respect', u'both', u'because', u'it', u'is', u'god', u'intricate', u'handiwork', u'and', u'the', u'health', u'of', u'future', u'generation', u'and', u'because', u'showing', u'the', u'facet', u'of', u'one', u'who', u'is', u'disregardful', u'of', u'such', u'thing', u'doe', u'not', u'constitute', u'what', u'the', u'apostle', u'paul', u'called', u'becoming', u'all', u'thing', u'to', u'all', u'men', u'so', u'that', u'by', u'all', u'possible', u'mean', u'might', u'save', u'some', u'don', u'say', u'forget', u'the', u'environment', u've', u'got', u'important', u'thing', u'to', u'spend', u'my', u'time', u'on', u'putting', u'your', u'foot', u'in', u'your', u'mouth', u'in', u'this', u'manner', u'will', u'destroy', u'your', u'credibility', u'in', u'expressing', u'the', u'thing', u'that', u'are', u'more', u'important', u'show', u'that', u'it', u'is', u'not', u'the', u'ultimate', u'entity', u'that', u'it', u'is', u'creature', u'and', u'not', u'creator', u'show', u'that', u'it', u'beauty', u'and', u'glory', u'point', u'to', u'greater', u'beauty', u'and', u'glory', u'show', u'that', u'it', u'is', u'not', u'the', u'ultimate', u'tapestry', u'but', u'one', u'of', u'many', u'cord', u'woven', u'in', u'the', u'infinite', u'tapestry']
# [u'it', u'depends', u'on', u'your', u'priority', u'lot', u'of', u'people', u'put', u'higher', u'priority', u'on', u'gas', u'mileage', u'and', u'cost', u'than', u'on', u'safety', u'buying', u'unsafe', u'econoboxes', u'instead', u'of', u'volvos', u'personally', u'take', u'middle', u'ground', u'the', u'only', u'thing', u'really', u'look', u'for', u'is', u'three', u'point', u'seatbelt', u'and', u'mph', u'bumper', u'figure', u'that', u'mph', u'collision', u'into', u'brick', u'wall', u'aren', u'common', u'enough', u'for', u'me', u'to', u'spend', u'that', u'much', u'extra', u'money', u'for', u'protection', u'but', u'there', u'are', u'lot', u'of', u'low', u'speed', u'collision', u'that', u'do', u'worry', u'me']
# [u'the', u'front', u'cover', u'should', u'be', u'available', u'from', u'sony', u'check', u'with', u'local', u'car', u'stereo', u'shop', u'you', u'will', u'probably', u'definitely', u'have', u'to', u'provide', u'the', u'unit', u'serial', u'number', u'and', u'hopefully', u'you', u'had', u'registered', u'the', u'warranty', u'card', u'don', u'know', u'the', u'cost', u'but', u'replacement', u'have', u'to', u'be', u'available', u'to', u'people', u'who', u'damage', u'the', u'face', u'cover', u'so', u'it', u'stand', u'to', u'reason', u'that', u'it', u'can', u'be', u'replaced', u'a', u'to', u'deterring', u'theft', u'when', u'worked', u'for', u'stereo', u'shop', u'we', u'referred', u'the', u'customer', u'to', u'sony', u'number', u'we', u'would', u'not', u'sell', u'the', u'face', u'nor', u'did', u'we', u'have', u'them', u'available', u'most', u'people', u'who', u'came', u'in', u'asking', u'for', u'the', u'face', u'cover', u'or', u'pullout', u'sleave', u'for', u'that', u'matter', u'would', u'look', u'very', u'disheartened', u'to', u'find', u'that', u'they', u'acquired', u'deck', u'they', u'couldn', u'use', u'if', u'theft', u'occurs', u'with', u'these', u'deck', u'notify', u'sony', u'serial', u'number', u'do', u'catch', u'theives']
# [u'my', u'son', u'ha', u'the', u'usual', u'teenage', u'spotty', u'chin', u'and', u'greasy', u'nose', u'bought', u'him', u'clearasil', u'face', u'wash', u'and', u'ointment', u'think', u'that', u'is', u'probably', u'enough', u'along', u'with', u'the', u'usual', u'good', u'diet', u'however', u'he', u'is', u'on', u'at', u'me', u'to', u'get', u'some', u'product', u'called', u'dalacin', u'which', u'used', u'to', u'be', u'doctor', u'prescription', u'only', u'treatment', u'but', u'is', u'not', u'available', u'over', u'the', u'chemist', u'counter', u'have', u'asked', u'couple', u'of', u'pharmacist', u'who', u'say', u'either', u'his', u'acne', u'is', u'not', u'severe', u'enough', u'for', u'dalacin', u'or', u'that', u'clearasil', u'is', u'ok', u'had', u'the', u'odd', u'spot', u'a', u'teenager', u'nothing', u'serious', u'his', u'father', u'wa', u'the', u'same', u'so', u'don', u'figure', u'his', u'acne', u'is', u'going', u'to', u'escalate', u'into', u'something', u'disfiguring', u'but', u'know', u'kid', u'are', u'senstitive', u'about', u'their', u'appearance', u'am', u'wary', u'because', u'neighbour', u'son', u'had', u'this', u'wierd', u'malady', u'that', u'wa', u'eventually', u'put', u'down', u'to', u'an', u'overdose', u'of', u'vitamin', u'from', u'acne', u'treatment', u'want', u'to', u'help', u'but', u'with', u'appropriate', u'treatment', u'my', u'son', u'also', u'ha', u'some', u'scaliness', u'around', u'the', u'hairline', u'on', u'his', u'scalp', u'sort', u'of', u'teenage', u'cradle', u'cap', u'any', u'pointer', u'advice', u'on', u'this', u'we', u'have', u'tried', u'couple', u'of', u'anti', u'dandruff', u'shampoo', u'and', u'some', u'of', u'these', u'are', u'inclined', u'to', u'make', u'the', u'condition', u'worse', u'not', u'better', u'shall', u'bury', u'the', u'kid', u'till', u'he']
# [u'just', u'a', u'not', u'of', u'possible', u'interest', u'on', u'this', u'subject', u'it', u'is', u'my', u'understanding', u'that', u'exploding', u'television', u'were', u'major', u'cause', u'of', u'domestic', u'accident', u'in', u'the', u'soviet', u'union', u'in', u'past', u'year']
# [u'how', u'do', u'you', u'define', u'war', u'do', u'seiges', u'and', u'constant', u'attack', u'on', u'villiages', u'count', u'a', u'act', u'of', u'war', u'or', u'is', u'that', u'only', u'when', u'the', u'jew', u'do', u'them', u'january', u'arab', u'liberation', u'army', u'attack', u'kfar', u'szold', u'men', u'attack', u'kfar', u'etzion', u'mile', u'south', u'of', u'jerusalem', u'after', u'cutting', u'off', u'the', u'supply', u'line', u'to', u'it', u'attack', u'on', u'yehiam', u'western', u'galilee', u'and', u'kibbutz', u'tirat', u'tzvi', u'by', u'mid', u'march', u'the', u'jewish', u'settlement', u'in', u'the', u'negev', u'had', u'been', u'cut', u'off', u'from', u'land', u'link', u'with', u'the', u'rest', u'of', u'the', u'jewish', u'population', u'the', u'etzion', u'group', u'of', u'villiages', u'near', u'hebron', u'had', u'been', u'cut', u'off', u'while', u'member', u'of', u'convoy', u'trying', u'to', u'supply', u'yehiam', u'were', u'slaughtered', u'cutting', u'off', u'the', u'villiage', u'jerusalem', u'wa', u'under', u'seige', u'being', u'cut', u'off', u'from', u'it', u'supply', u'route', u'from', u'tel', u'aviv', u'the', u'bombed', u'out', u'supply', u'truck', u'have', u'been', u'left', u'on', u'the', u'side', u'of', u'that', u'road', u'to', u'this', u'day', u'in', u'memoriam', u'by', u'this', u'time', u'jew', u'had', u'been', u'killed', u'of', u'course', u'this', u'isn', u'war', u'since', u'it', u'only', u'the', u'arab', u'attacking', u'just', u'like', u'last', u'week', u'when', u'the', u'fatah', u'launched', u'katyusha', u'rocket', u'against', u'northern', u'israel', u'where', u'doe', u'uprising', u'end', u'and', u'war', u'begin', u'will', u'it', u'still', u'be', u'intifadah', u'when', u'the', u'plo', u'brings', u'in', u'tank']
# [u'once', u'again', u'it', u'appears', u'that', u'the', u'one', u'eyed', u'man', u'ha', u'appeared', u'in', u'the', u'land', u'of', u'the', u'sighted', u'and', u'for', u'some', u'strange', u'resaon', u'ha', u'appointed', u'himself', u'the', u'ruler', u'and', u'supreme', u'power']
# [u'funny', u'you', u'should', u'mention', u'this', u'one', u'time', u'on', u'hnic', u'don', u'cherry', u'pointed', u'out', u'vanbiesbrouck', u'mask', u'he', u'hated', u'it', u'think', u'he', u'said', u'something', u'to', u'the', u'effect', u'of', u'you', u'see', u'he', u'wa', u'great', u'last', u'year', u'now', u'he', u'go', u'out', u'and', u'get', u'that', u'dopey', u'mask', u'and', u'he', u'can', u'stop', u'beachball', u'you', u'may', u'or', u'may', u'not', u'take', u'cherry', u'seriously', u'at', u'all', u'but', u'cracked', u'up', u'when', u'heard', u'it']
# [u'oh', u'boy', u'little', u'bike', u'versus', u'scuffling', u'grow', u'up', u'and', u'that', u'go', u'for', u'the', u'both', u'of', u'you', u'do', u'hope', u'that', u'the', u'dump', u'dempster', u'campaign', u'work', u'however', u'think', u'that', u'he', u'is', u'crook', u'and', u'am', u'suprised', u'that', u'it', u'ha', u'taken', u'this', u'long', u'for', u'anything', u'to', u'be', u'done', u'though', u'obviously', u'it', u'ain', u'over', u'yet', u'on', u'the', u'other', u'hand', u'not', u'sure', u'that', u'want', u'to', u'be', u'in', u'bed', u'with', u'any', u'of', u'the', u'wacko', u'running', u'throwing', u'oo', u'down', u'rathole', u'might', u'be', u'more', u'effective', u'than', u'sending', u'it', u'in', u'to', u'the', u'club', u'you', u'wouldn', u'get', u'anything', u'but', u'you', u'don', u'get', u'anything', u'now', u'the', u'magazine', u'you', u'say', u'ever', u'since', u'the', u'moa', u'politburo', u'installed', u'don', u'it', u'ha', u'lacked', u'any', u'sort', u'of', u'panache', u'it', u'may', u'have', u'had', u'ah', u'but', u'what', u'would', u'know', u'own', u'and', u'bike']
# ...
# [u'your', u'bad', u'english', u'see', u'quote', u'above', u'you', u'lose', u'that', u'wager', u'if', u'the', u'supporting', u'argument', u'were', u'part', u'of', u'it', u'did', u'you', u'know', u'that', u'hitler', u'himself', u'wa', u'devout', u'christian', u'and', u'heterosexual', u'drywid']
# [u'could', u'you', u'explain', u'what', u'any', u'of', u'this', u'pertains', u'to', u'is', u'this', u'position', u'statement', u'on', u'something', u'or', u'typing', u'practice', u'and', u'why', u'are', u'you', u'using', u'my', u'name', u'do', u'you', u'think', u'this', u'relates', u'to', u'anything', u've', u'said', u'and', u'if', u'so', u'what']
# [u'hi', u'don', u'know', u'much', u'about', u'mormon', u'and', u'want', u'to', u'know', u'about', u'serious', u'independent', u'study', u'about', u'the', u'book', u'of', u'mormon', u'don', u'buy', u'the', u'official', u'story', u'about', u'the', u'gold', u'original', u'taken', u'to', u'heaven', u'but', u'haven', u'read', u'the', u'book', u'of', u'mormon', u'by', u'myself', u'have', u'to', u'much', u'work', u'learning', u'biblical', u'hebrew', u'will', u'appreciate', u'any', u'comment', u'about', u'the', u'result', u'of', u'study', u'in', u'style', u'vocabulary', u'place', u'name', u'internal', u'consistency', u'and', u'so', u'on', u'for', u'example', u'there', u'is', u'evidence', u'for', u'one', u'writer', u'or', u'multiple', u'writer', u'there', u'are', u'some', u'mention', u'about', u'event', u'place', u'or', u'historical', u'person', u'later', u'discovered', u'by', u'archeologist', u'yours', u'in', u'collen', u'andres', u'grino', u'brandt', u'casilla', u'santiago', u'agrino', u'enkidu', u'mic', u'cl', u'chile']
# [u'riveting', u'bmwmoa', u'election', u'soap', u'opera', u'detail', u'deleted', u'going', u'to', u'buy', u'bmw', u'just', u'to', u'cast', u'vote', u'for', u'groucho', u'ride', u'safe']
# [u'the', u'sophomore', u'roman', u'the', u'sophomore', u'say', u'what', u'is', u'truth', u'and', u'turn', u'to', u'bask', u'in', u'the', u'admiration', u'of', u'his', u'peer', u'how', u'modern', u'how', u'daring', u'how', u'liberating', u'how', u'modern', u'how', u'daring', u'how', u'liberating', u'they', u'chant', u'the', u'sophomore', u'being', u'american', u'doesn', u'know', u'that', u'his', u'question', u'modern', u'skeptical', u'cynical', u'wa', u'asked', u'before', u'by', u'modern', u'skeptical', u'cynical', u'urbane', u'cosmopolitan', u'politician', u'appointed', u'not', u'elected', u'who', u'happened', u'to', u'live', u'two', u'thousand', u'year', u'ago', u'like', u'many', u'politician', u'he', u'cared', u'le', u'about', u'ideal', u'than', u'result', u'le', u'about', u'end', u'than', u'mean', u'le', u'about', u'anything', u'than', u'keeping', u'his', u'job', u'and', u'his', u'head', u'we', u'might', u'call', u'him', u'bit', u'brutal', u'though', u'firm', u'would', u'be', u'kinder', u'and', u'no', u'doubt', u'stalin', u'who', u'let', u'nobody', u'go', u'laughed', u'at', u'his', u'laxness', u'he', u'didn', u'like', u'his', u'job', u'perhaps', u'he', u'no', u'longer', u'hoped', u'for', u'better', u'nor', u'feared', u'worse', u'except', u'regarding', u'his', u'head', u'and', u'when', u'these', u'wily', u'jew', u'with', u'their', u'head', u'win', u'tail', u'you', u'lose', u'conundrum', u'brought', u'forth', u'their', u'madman', u'his', u'first', u'impulse', u'wa', u'to', u'play', u'the', u'roman', u'find', u'nothing', u'wrong', u'with', u'him', u'see', u'to', u'it', u'yourselves', u'but', u'when', u'they', u'mentioned', u'king', u'and', u'caesar', u'his', u'heart', u'froze', u'if', u'he', u'killed', u'their', u'madman', u'he', u'start', u'riot', u'and', u'lose', u'his', u'job', u'and', u'his', u'head', u'if', u'he', u'saved', u'the', u'king', u'of', u'the', u'jew', u'he', u'piss', u'off', u'caesar', u'and', u'lose', u'his', u'job', u'and', u'his', u'head', u'and', u'when', u'his', u'wife', u'told', u'him', u'to', u'have', u'nothing', u'to', u'do', u'with', u'the', u'righteous', u'lout', u'she', u'didn', u'tell', u'him', u'anything', u'he', u'hadn', u'already', u'figured', u'out', u'so', u'he', u'punted', u'not', u'my', u'jurisdiction', u'take', u'him', u'to', u'see', u'herod', u'who', u'just', u'happened', u'to', u'be', u'in', u'town', u'herod', u'appreciated', u'the', u'courtesy', u'but', u'wasn', u'worried', u'and', u'sent', u'the', u'sharp', u'tongued', u'fool', u'who', u'suddenly', u'didn', u'have', u'much', u'to', u'say', u'funny', u'how', u'people', u'lose', u'it', u'under', u'pressure', u'back', u'in', u'the', u'attire', u'proper', u'to', u'his', u'royal', u'state', u'his', u'as', u'is', u'covered', u'if', u'herod', u'ha', u'no', u'problem', u'caesar', u'certainly', u'won', u'the', u'fool', u'can', u'be', u'king', u'of', u'whatever', u'world', u'he', u'want', u'a', u'long', u'a', u'it', u'not', u'caesar', u'letting', u'him', u'go', u'he', u'said', u'with', u'shout', u'look', u'like', u'he', u'll', u'last', u'this', u'one', u'out', u'the', u'crowd', u'reaction', u'puzzled', u'him', u'they', u'really', u'wanted', u'him', u'dead', u'they', u'didn', u'want', u'the', u'king', u'of', u'the', u'jew', u'they', u'wanted', u'barabbas', u'instead', u'and', u'a', u'josephus', u'record', u'they', u'got', u'him', u'oh', u'well', u'he', u'thought', u'they', u'all', u'look', u'the', u'same', u'to', u'me', u'and', u'we', u'll', u'get', u'barabbas', u'next', u'time', u'and', u'if', u'can', u'get', u'them', u'to', u'say', u'we', u'have', u'no', u'king', u'but', u'caesar', u'by', u'killing', u'madman', u'hell', u'll', u'kill', u'ten', u'day', u'and', u'then', u'pilate', u'had', u'his', u'fun', u'little', u'joke', u'short', u'to', u'the', u'point', u'trilingual', u'and', u'all', u'this', u'went', u'a', u'it', u'always', u'doe', u'when', u'someone', u'get', u'caught', u'in', u'the', u'gear', u'of', u'government', u'and', u'there', u'scien ...
# [u'a', u've', u'said', u'before', u'there', u'no', u'reliable', u'way', u'to', u'find', u'out', u'the', u'size', u'of', u'the', u'window', u'manager', u'decoration', u'if', u'your', u'window', u'ha', u'been', u'reparented', u'you', u'can', u'assume', u'that', u'the', u'window', u'you', u're', u'parented', u'to', u'is', u'the', u'window', u'that', u'hold', u'all', u'of', u'the', u'window', u'manager', u'decoration', u'there', u'may', u'be', u'several', u'layer', u'of', u'window', u'doing', u'multiple', u'xquerytree', u'until', u'you', u'get', u'to', u'the', u'root', u'will', u'work', u'in', u'most', u'case', u'but', u'there', u'no', u'guarantee', u'that', u'the', u'outside', u'decoration', u'window', u'is', u'parented', u'to', u'the', u'root', u'window', u'of', u'the', u'display', u'tvtwm']
# [u'sanjay', u'sinha', u'on', u'the', u'apr', u'gmt', u'wibbled', u'thanks', u'to', u'everyone', u'who', u'posted', u'in', u'my', u'previous', u'quest', u'for', u'camping', u'info', u'another', u'question', u'well', u'not', u'strictly', u'stuff', u'am', u'looking', u'for', u'thermos', u'flask', u'to', u'keep', u'coffee', u'hot', u'mean', u'real', u'hot', u'of', u'course', u'it', u'must', u'be', u'the', u'unbreakable', u'type', u'so', u'far', u'what', u'ever', u'metal', u'type', u'have', u'wasted', u'money', u'on', u'ha', u'not', u'matched', u'the', u'vacuum', u'glass', u'type', u'any', u'info', u'appreciated', u'sanjay', u'back', u'in', u'my', u'youth', u'ahem', u'the', u'wiffy', u'and', u'moi', u'purchased', u'gadget', u'which', u'heated', u'up', u'water', u'from', u'source', u'it', u'wa', u'for', u'car', u'use', u'but', u'we', u'thought', u'we', u'try', u'it', u'on', u'my', u'rd', u'it', u'worked', u'ok', u'apart', u'from', u'one', u'slight', u'problem', u'we', u'had', u'to', u'keep', u'the', u'rev', u'above', u'any', u'lower', u'and', u'the', u'motor', u'would', u'die', u'from', u'lack', u'of', u'electron', u'movement', u'it', u'made', u'for', u'interesting', u'cup', u'of', u'coffee', u'anyhow', u'we', u'would', u'plot', u'route', u'that', u'contained', u'straight', u'of', u'over', u'three', u'mile', u'so', u'that', u'we', u'had', u'sufficient', u'time', u'to', u'get', u'the', u'water', u'to', u'boiling', u'point', u'this', u'is', u'sometimes', u'difficult', u'in', u'england', u'good', u'luck', u'on', u'your', u'quest', u'nick', u'the', u'biker', u'dod', u'concise', u'oxford', u'lud']
# [u'what', u'exactly', u'doe', u'the', u'window', u'bitmap', u'format', u'look', u'like', u'mean', u'how', u'is', u'the', u'data', u'stored', u'width', u'height', u'no', u'of', u'colour', u'bitmap', u'data', u'couldn', u'find', u'anything', u'in', u'th', u'user', u'manual', u'is', u'there', u'any', u'other', u'reference', u'material', u'which', u'would', u'give', u'me', u'this', u'information']
# [u'once', u'it', u'hit', u'land', u'you', u'can', u'record', u'it', u'if', u'you', u'have', u'telco', u'access', u'the', u'telco', u'isn', u'supposed', u'to', u'give', u'that', u'without', u'warrant', u'that', u'the', u'rule', u'today', u'but', u'even', u'so', u'the', u'evidence', u'would', u'not', u'be', u'admissible', u'think', u'unless', u'the', u'judge', u'so', u'ordered', u'think', u'that', u'even', u'interception', u'of', u'the', u'crypttext', u'without', u'warrant', u'would', u'be', u'illegal', u'cop', u'can', u'record', u'today', u'plain', u'cellular', u'call', u'and', u'then', u'ask', u'judge', u'hey', u'can', u'we', u'have', u'permission', u'to', u'listen', u'to', u'those', u'tape', u'can', u'they', u'how', u'long', u'do', u'you', u'think', u'it', u'will', u'be', u'before', u'it', u'becomes', u'legal', u'for', u'the', u'police', u'to', u'record', u'encrypted', u'conversation', u'it', u'not', u'violating', u'your', u'privacy', u'because', u'we', u'can', u'read', u'the', u'encryption', u'without', u'warrant', u'with', u'the', u'usual', u'good', u'faith', u'exception', u'if', u'they', u'accidentally', u'record', u'non', u'encrypted', u'conversation', u'besides', u'it', u'covered', u'by', u'the', u'drug', u'exception', u'to', u'the', u'fourth', u'amendment']
# [u've', u'used', u'with', u'classic', u'set', u'for', u'both', u'and', u'you', u'can', u'choose', u'which', u'resolution', u'you', u'want', u'in', u'the', u'prom', u'monitor', u'before', u'booting', u'one', u'person', u'had', u'trouble', u'with', u'that', u'wa', u'fixed', u'by', u'using', u'the', u'multi', u'screen', u'version', u'here', u'how', u'our', u'version', u'wa', u'built', u'you', u'can', u'just', u'copy', u'usr', u'local', u'bin', u'xsun', u'from', u'farside', u'rutgers', u'edu', u'if', u'you', u'just', u'want', u'to', u'see', u'whether', u'this', u'version', u'will', u'work', u'distribution', u'installed', u'from', u'pub', u'mit', u'and', u'contrib', u'on', u'export', u'lcs', u'mit', u'edu', u'patch', u'installed', u'from', u'pub', u'fix', u'on', u'export', u'xsun', u'multi', u'screen', u'patch', u'installed', u'from', u'contrib', u'xsun', u'multi', u'screen', u'on', u'export', u'mar', u'solaris', u'patch', u'installed', u'release', u'update', u'from', u'contrib', u'sunos', u'patch', u'on', u'export', u'mar']
# [u'sure', u'can', u'the', u'illustrated', u'encyclopedia', u'of', u'motorcycle', u'edited', u'by', u'erwin', u'tragatsch', u'wa', u'published', u'by', u'the', u'hamlyn', u'publishing', u'group', u'limited', u'astronaut', u'house', u'hounslow', u'road', u'feltham', u'middlesex', u'england', u'it', u'wa', u'first', u'published', u'in', u'and', u'mine', u'wa', u'reprinted', u'in', u'cost', u'then', u'wa', u'pound', u'in', u'the', u'uk', u'though', u'paid', u'for', u'it', u'in', u'canadian', u'dollar', u'have', u'no', u'idea', u'whether', u'it', u'still', u'in', u'print', u'perhaps', u'you', u'could', u'let', u'the', u'net', u'know', u'bob']
# [u'you', u'will', u'need', u'driver', u'ver', u'to', u'work', u'with', u'quadra', u'centris', u'you', u'can', u'download', u'it', u'from', u'iomega', u'bb']
# [u'archive', u'name', u'cryptography', u'faq', u'part', u'last', u'modified', u'faq', u'for', u'sci', u'crypt', u'part', u'basic', u'cryptology', u'this', u'is', u'the', u'third', u'of', u'ten', u'part', u'of', u'the', u'sci', u'crypt', u'faq', u'the', u'part', u'are', u'mostly', u'independent', u'but', u'you', u'should', u'read', u'the', u'first', u'part', u'before', u'the', u'rest', u'we', u'don', u'have', u'the', u'time', u'to', u'send', u'out', u'missing', u'part', u'by', u'mail', u'so', u'don', u'ask', u'note', u'such', u'a', u'kah', u'refer', u'to', u'the', u'reference', u'list', u'in', u'the', u'last', u'part', u'the', u'section', u'of', u'this', u'faq', u'are', u'available', u'via', u'anonymous', u'ftp', u'to', u'rtfm', u'mit', u'edu', u'a', u'pub', u'usenet', u'news', u'answer', u'cryptography', u'faq', u'part', u'xx', u'the', u'cryptography', u'faq', u'is', u'posted', u'to', u'the', u'newsgroups', u'sci', u'crypt', u'sci', u'answer', u'and', u'news', u'answer', u'every', u'day', u'content', u'what', u'is', u'cryptology', u'cryptography', u'plaintext', u'ciphertext', u'encryption', u'key', u'what', u'reference', u'can', u'start', u'with', u'to', u'learn', u'cryptology', u'how', u'doe', u'one', u'go', u'about', u'cryptanalysis', u'what', u'is', u'brute', u'force', u'search', u'and', u'what', u'is', u'it', u'cryptographic', u'relevance', u'what', u'are', u'some', u'property', u'satisfied', u'by', u'every', u'strong', u'cryptosystem', u'if', u'cryptosystem', u'is', u'theoretically', u'unbreakable', u'then', u'is', u'it', u'guaranteed', u'analysis', u'proof', u'in', u'practice', u'why', u'are', u'many', u'people', u'still', u'using', u'cryptosystems', u'that', u'are', u'relatively', u'easy', u'to', u'break', u'what', u'is', u'cryptology', u'cryptography', u'plaintext', u'ciphertext', u'encryption', u'key', u'the', u'story', u'begin', u'when', u'julius', u'caesar', u'sent', u'message', u'to', u'his', u'trusted', u'acquaintance', u'he', u'didn', u'trust', u'the', u'messenger', u'so', u'he', u'replaced', u'every', u'by', u'every', u'by', u'and', u'so', u'on', u'through', u'the', u'alphabet', u'only', u'someone', u'who', u'knew', u'the', u'shift', u'by', u'rule', u'could', u'decipher', u'his', u'message', u'cryptosystem', u'or', u'cipher', u'system', u'is', u'method', u'of', u'disguising', u'message', u'so', u'that', u'only', u'certain', u'people', u'can', u'see', u'through', u'the', u'disguise', u'cryptography', u'is', u'the', u'art', u'of', u'creating', u'and', u'using', u'cryptosystems', u'cryptanalysis', u'is', u'the', u'art', u'of', u'breaking', u'cryptosystems', u'seeing', u'through', u'the', u'disguise', u'even', u'when', u'you', u're', u'not', u'supposed', u'to', u'be', u'able', u'to', u'cryptology', u'is', u'the', u'study', u'of', u'both', u'cryptography', u'and', u'cryptanalysis', u'the', u'original', u'message', u'is', u'called', u'plaintext', u'the', u'disguised', u'message', u'is', u'called', u'ciphertext', u'encryption', u'mean', u'any', u'procedure', u'to', u'convert', u'plaintext', u'into', u'ciphertext', u'decryption', u'mean', u'any', u'procedure', u'to', u'convert', u'ciphertext', u'into', u'plaintext', u'cryptosystem', u'is', u'usually', u'whole', u'collection', u'of', u'algorithm', u'the', u'algorithm', u'are', u'labelled', u'the', u'label', u'are', u'called', u'key', u'for', u'instance', u'caesar', u'probably', u'used', u'shift', u'by', u'encryption', u'for', u'several', u'different', u'value', u'of', u'it', u'natural', u'to', u'say', u'that', u'is', u'the', u'key', u'here', u'the', u'people', u'who', u'are', u'supposed', u'to', u'be', u'able', u'to', u'see', u'through', u'the', u'disguise', u'are', u'called', u'recipient', u'other', u'people', u'are', u'enemy', u'opponent', u'interloper', u'eavesdropper', u'or', u'third', u'party', u'what', u'reference', u'can', u'start', u'with', u'to', u'learn', u'cryptology', u'for', u'an', u'introduction', u'to', u'technical', u'matter', u'the', u'survey', u'article ...

# %%
#from sklearn.feature_extraction.text import TfidfTransformer
#tfidf_transformer = TfidfTransformer()
#X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
#print (X_train_tfidf)
# X_train_tfidf.toarray()[:30,:10]

# %%
#  nltk.download()

# %% [markdown]
# ### Problem (c)

# %%
def get_max_feature(fileName):
    categories = [fileName]
    twenty_train_c = fetch_20newsgroups(subset='train', categories=categories, shuffle=True, random_state=42)
    count_vect_c = TfidfVectorizer(tokenizer=tokenize_and_stem,min_df=1,max_features=10, stop_words= stop_words, token_pattern='[a-zA-Z]{2,}')
#     count_vect_c = TfidfVectorizer(min_df=1, max_features=10, stop_words= stop_words, token_pattern='[a-zA-Z]{2,}')
    X_train_counts_c = count_vect_c.fit_transform(twenty_train_c.data)
    return count_vect_c.vocabulary_.keys()


print (get_max_feature('comp.sys.ibm.pc.hardware'))
print (get_max_feature('comp.sys.mac.hardware'))
print (get_max_feature('misc.forsale'))
print (get_max_feature('soc.religion.christian'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6a61ceecacc3> in <module>()
#       8
#       9
# ---> 10 print (get_max_feature('comp.sys.ibm.pc.hardware'))
#      11 print (get_max_feature('comp.sys.mac.hardware'))
#      12 print (get_max_feature('misc.forsale'))
#
# <ipython-input-1-6a61ceecacc3> in get_max_feature(fileName)
#       1 def get_max_feature(fileName):
#       2     categories = [fileName]
# ----> 3     twenty_train_c = fetch_20newsgroups(subset='train', categories=categories, shuffle=True, random_state=42)
#       4     count_vect_c = TfidfVectorizer(tokenizer=tokenize_and_stem,min_df=1,max_features=10, stop_words= stop_words, token_pattern='[a-zA-Z]{2,}')
#       5 #     count_vect_c = TfidfVectorizer(min_df=1, max_features=10, stop_words= stop_words, token_pattern='[a-zA-Z]{2,}')
#
# NameError: global name 'fetch_20newsgroups' is not defined

# %% [markdown]
# ### Problem (d)

# %%
from sklearn.decomposition import TruncatedSVD
tsv = TruncatedSVD(n_components=50,algorithm='arpack')
X_train_lsi = tsv.fit_transform(X_train_counts)
print (X_train_lsi.shape)
# Out:
# (11314, 50)

# %% [markdown]
# ### Problem (e)

# %%
categories = ['comp.graphics','comp.os.ms-windows.misc','comp.sys.ibm.pc.hardware','comp.sys.mac.hardware','rec.autos','rec.motorcycles','rec.sport.baseball','rec.sport.hockey']
twenty_train = fetch_20newsgroups(subset='train', categories=categories, shuffle=True, random_state=42, remove = ('headers', 'footers','quotes'))
twenty_test = fetch_20newsgroups(subset='test', categories=categories, shuffle=True, random_state=42, remove = ('headers', 'footers','quotes'))

twenty_train_target = [ int(x / 4) for x in twenty_train.target]
twenty_test_target = [ int(x / 4) for x in twenty_test.target]
#print twenty_test_target
#count_vect = TfidfVectorizer(min_df=1, stop_words= stop_words, token_pattern='[a-zA-Z]{2,}')
#X_train_counts = count_vect.fit_transform(twenty_train.data)
#print twenty_train.target
#print twenty_train_target

# %%
def data_process(twenty_test):
#     count_vect_test = TfidfVectorizer(min_df=1, stop_words= stop_words, token_pattern='[a-zA-Z]{2,}')
    count_vect_test = TfidfVectorizer(tokenizer=tokenize_and_stem,min_df=2,stop_words= stop_words, token_pattern='[a-zA-Z]{2,}')
    X_test_counts = count_vect_test.fit_transform(twenty_test.data)
    tsv_test = TruncatedSVD(n_components=50,algorithm='arpack')
    X_test_lsi = tsv_test.fit_transform(X_test_counts)
    return X_test_lsi

# %%
from sklearn.svm import LinearSVC
X_train_lsi=data_process(twenty_train)
clf = LinearSVC(C=10e20).fit(X_train_lsi, twenty_train_target)

# %%
X_test_lsi = data_process(twenty_test)
predicted = clf.predict(X_test_lsi)
print predicted
score = clf.score(X_test_lsi, twenty_test_target)
print score
# Out:
# [0 0 1 ..., 1 0 0]
# 0.78253968254

# %%
from sklearn.metrics import roc_curve, auc
y_score=clf.decision_function(X_test_lsi)
fpr, tpr, _ = roc_curve(twenty_test_target, y_score)
#average_precision = average_precision_score(twenty_test.target, y_score)
roc_auc = auc(fpr, tpr)


plt.figure()
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-d4994d252543> in <module>()
#       6
#       7
# ----> 8 plt.figure()
#       9 plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
#      10 plt.plot([0, 1], [0, 1], 'k--')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ##### Confusion matrix. [Reference Link](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html)

# %%
from sklearn.metrics import confusion_matrix
y_true = twenty_test_target
y_pred = predicted
print confusion_matrix(y_true, y_pred)
# Out:
# [[1106  454]
#  [ 231 1359]]

# %% [markdown]
# ##### Accuracy [Reference Link](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html)

# %%
from sklearn.metrics import accuracy_score
y_true = twenty_test_target
y_pred = predicted
print accuracy_score(y_true, y_pred)
# Out:
# 0.78253968254

# %% [markdown]
# ##### Precision [Reference Link](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.precision_score.html#sklearn.metrics.precision_score)

# %%
from sklearn.metrics import precision_score
y_true = twenty_test_target
y_pred = predicted
precision_score(y_true, y_pred)
# Out:
# 0.74958632101489242

# %% [markdown]
# ##### Recall [Reference Link](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.recall_score.html)

# %%
from sklearn.metrics import recall_score
y_true = twenty_test_target
y_pred = predicted
recall_score(y_true, y_pred)
# Out:
# 0.8547169811320755

# %% [markdown]
# ##### Recall and precision of your classifier. [Reference Link](http://scikit-learn.org/stable/auto_examples/model_selection/plot_precision_recall.html)

# %%
#from sklearn.metrics import precision_recall_curve
#from sklearn.metrics import average_precision_score
#from sklearn.preprocessing import label_binarize
#X_train = X_train_lsi
#X_test = X_test_lsi
#y_train = twenty_train.target
#y_test = twenty_test.target
#y_score = clf.decision_function(X_test_lsi)
#y = label_binarize(twenty_train.target, classes=[0, 1])
# n_classes = y.shape
#print n_classes
# Compute Precision-Recall and plot curve
#precision = dict()
#recall = dict()
#average_precision = dict()
#for i in range(n_classes):
#precision, recall, _ = precision_recall_curve(y_test,y_score)    
#average_precision = average_precision_score(y_test, y_score)
#average_recall = average_recall_score(y_test, y_score)

#print precision
#print recall
#print average_precision
#print average_recall

# %% [markdown]
# ### Problem (f)

# %%
from sklearn.cross_validation import KFold
kf = KFold(n=len(twenty_train_target), n_folds=5, shuffle=False, random_state=None)
twenty_train_data = data_process(twenty_train)
twenty_test_data = data_process(twenty_test)
l = [[0]*7 for i in range(5)]
i=0
j=0
#la=[]
for train_index, test_index in kf:
    #print train_index
    #[ int(x / 4) for x in twenty_train.target]
    X_train_soft, X_test_soft = twenty_train_data[train_index], twenty_train_data[test_index]
    for k in [-3, -2, -1, 0, 1, 2, 3]:
        target_train = [ int(x / 4) for x in twenty_train.target[train_index]]
        target_test = [ int(x / 4) for x in twenty_train.target[test_index]]
        clf_soft = LinearSVC(C=10**k).fit(X_train_soft, target_train)
        #predicted_soft = clf.predict(X_test_soft_lsi)
        score = clf_soft.score(X_test_soft, target_test)
        #if k==1:
        #    print score
        #la.append(score)
        l[i][j]=score
        j=j+1
        #print 1
    i=i+1
    j=0

#print train_index
#twenty_train.data
#print (l)
#print la
# twenty_train_target[1]

# %%
#twenty_train.target[train_index]

# %%
average_s = list(map(lambda x: (x[0]+x[1]+x[2]+x[3]+x[4])/5, zip(l[0], l[1], l[2], l[3], l[4])))
#print average_s
value = max(average_s)
index=average_s.index(value)
#print index
penalty = [-3, -2, -1, 0, 1, 2, 3]
print ('The best penalty value is',10**penalty[index])
# Out:
# ('The best penalty value is', 100)

# %%
clf_soft_pre = LinearSVC(C=10**1).fit(twenty_train_data, twenty_train_target)
predicted_soft_pre = clf_soft_pre.predict(twenty_test_data)

s = clf_soft_pre.score(twenty_test_data, twenty_test_target)
print s
# Out:
# 0.805079365079

# %% [markdown]
# ##### Confusion matrix. [Reference Link](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html)

# %%
from sklearn.metrics import confusion_matrix
y_true = twenty_test_target
y_pred = predicted_soft_pre
print confusion_matrix(y_true, y_pred)
# Out:
# [[1170  390]
#  [ 224 1366]]

# %%
from sklearn.metrics import roc_curve, auc
y_score=clf_soft_pre.decision_function(twenty_test_data)
fpr, tpr, _ = roc_curve(twenty_test_target, y_score)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-eb5a687d60ed> in <module>()
#       4 roc_auc = auc(fpr, tpr)
#       5
# ----> 6 plt.figure()
#       7 plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
#       8 plt.plot([0, 1], [0, 1], 'k--')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ##### Accuracy [Reference Link](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html)

# %%
from sklearn.metrics import accuracy_score
y_true = twenty_test_target
y_pred = predicted_soft_pre
print accuracy_score(y_true, y_pred)

# %% [markdown]
# ##### Precision [Reference Link](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.precision_score.html#sklearn.metrics.precision_score)

# %%
from sklearn.metrics import precision_score
y_true = twenty_test_target
y_pred = predicted_soft_pre
precision_score(y_true, y_pred)
# Out:
# 0.83457782883400344

# %% [markdown]
# ##### Recall [Reference Link](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.recall_score.html)

# %%
from sklearn.metrics import recall_score
y_true = twenty_test_target
y_pred = predicted_soft_pre
recall_score(y_true, y_pred)
# Out:
# 0.9138364779874214

# %% [markdown]
# ##### Recall and precision of your classifier. [Reference Link](http://scikit-learn.org/stable/auto_examples/model_selection/plot_precision_recall.html)

# %%
# from sklearn.metrics import precision_recall_curve
# from sklearn.metrics import average_precision_score
# from sklearn.preprocessing import label_binarize
# X_train = X_train_lsi
# X_test = X_test_lsi
# y_train = twenty_train.target
# y_test = twenty_test.target
# y_score = clf_soft_pre.decision_function(X_test_lsi)
# y = label_binarize(twenty_train.target, classes=[0, 1])
# # n_classes = y.shape
# #print n_classes
# # Compute Precision-Recall and plot curve
# precision = dict()
# recall = dict()
# average_precision = dict()
# #for i in range(n_classes):
# precision, recall, _ = precision_recall_curve(y_test,y_score)    
# average_precision = average_precision_score(y_test, y_score)

# # print precision
# # print recall
# print average_precision

# %% [markdown]
# ### Problem (g)

# %% [markdown]
# ##### Naïve Bayes Algorithm [Reference Link](http://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.GaussianNB.html)

# %%
X_test_lsi = data_process(twenty_test)
predicted = clf_naive_bayes.predict(X_test_lsi)
print predicted.shape
score = clf_naive_bayes.score(X_test_lsi, twenty_test_target)
print score
# Out:
# (3150,)
# 0.663492063492

# %% [markdown]
# ##### ROC curve [Reference Link](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_curve.html)

# %%
from sklearn.metrics import roc_curve, auc
y_score=clf_naive_bayes.predict_proba(X_test_lsi)[:, 1]
fpr, tpr, _ = roc_curve(twenty_test_target, y_score)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-5bf5ffe27946> in <module>()
#       4 roc_auc = auc(fpr, tpr)
#       5
# ----> 6 plt.figure()
#       7 plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
#       8 plt.plot([0, 1], [0, 1], 'k--')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ##### Confusion matrix. [Reference Link](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html)

# %%
from sklearn.metrics import confusion_matrix
y_true = twenty_test_target
y_pred = predicted
print confusion_matrix(y_true, y_pred)

# %%
from sklearn.naive_bayes import GaussianNB
clf_naive_bayes = GaussianNB().fit(X_train_lsi, twenty_train_target)

# %% [markdown]
# ##### Accuracy [Reference Link](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html)

# %%
from sklearn.metrics import accuracy_score
y_true = twenty_test_target
y_pred = predicted
print accuracy_score(y_true, y_pred)
# Out:
# 0.663492063492

# %% [markdown]
# ##### Precision [Reference Link](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.precision_score.html#sklearn.metrics.precision_score)

# %%
from sklearn.metrics import precision_score
y_true = twenty_test_target
y_pred = predicted
precision_score(y_true, y_pred)
# Out:
# 0.73123909249563701

# %% [markdown]
# ##### Recall [Reference Link](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.recall_score.html)

# %%
from sklearn.metrics import recall_score
y_true = twenty_test_target
y_pred = predicted
recall_score(y_true, y_pred)
# Out:
# 0.5270440251572327

# %% [markdown]
# ##### Recall and precision of your classifier. [Reference Link](http://scikit-learn.org/stable/auto_examples/model_selection/plot_precision_recall.html)

# %%
# from sklearn.metrics import precision_recall_curve
# from sklearn.metrics import average_precision_score
# from sklearn.preprocessing import label_binarize
# X_train = X_train_lsi
# X_test = X_test_lsi
# y_train = twenty_train.target
# y_test = twenty_test.target
# y_score = clf_naive_bayes.predict_proba(X_test_lsi)[:, 1]
# y = label_binarize(twenty_train.target, classes=[0, 1])
# # n_classes = y.shape
# #print n_classes
# # Compute Precision-Recall and plot curve
# precision = dict()
# recall = dict()
# average_precision = dict()
# #for i in range(n_classes):
# precision, recall, _ = precision_recall_curve(y_test,y_score)    
# average_precision = average_precision_score(y_test, y_score)
# #average_recall = average_recall_score(y_test, y_score)

# # print precision
# #print recall
# #print average_precision

# %% [markdown]
# ### Problem (h)

# %% [markdown]
# ###### logistic regression [Reference Link](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html)

# %%
from sklearn.linear_model import LogisticRegression
clf_logistic_regression = LogisticRegression().fit(X_train_lsi, twenty_train_target)

# %%
X_test_lsi = data_process(twenty_test)
predicted = clf_logistic_regression.predict(X_test_lsi)
print predicted.shape
score = clf_logistic_regression.score(X_test_lsi, twenty_test_target)
print score
# Out:
# (3150,)
# 0.848571428571

# %% [markdown]
# ##### ROC curve [Reference Link](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_curve.html)

# %%
from sklearn.metrics import roc_curve, auc
y_score=clf_logistic_regression.predict_proba(X_test_lsi)[:, 1]
fpr, tpr, _ = roc_curve(twenty_test_target, y_score)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-11a55724f638> in <module>()
#       4 roc_auc = auc(fpr, tpr)
#       5
# ----> 6 plt.figure()
#       7 plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
#       8 plt.plot([0, 1], [0, 1], 'k--')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ##### Confusion matrix. [Reference Link](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html)

# %%
from sklearn.metrics import confusion_matrix
y_true = twenty_test_target
y_pred = predicted
print confusion_matrix(y_true, y_pred)
# Out:
# [[1220  340]
#  [ 137 1453]]

# %% [markdown]
# ##### Accuracy [Reference Link](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html)

# %%
from sklearn.metrics import accuracy_score
y_true = twenty_test_target
y_pred = predicted
print accuracy_score(y_true, y_pred)
# Out:
# 0.848571428571

# %% [markdown]
# ##### Precision [Reference Link](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.precision_score.html#sklearn.metrics.precision_score)

# %%
from sklearn.metrics import precision_score
y_true = twenty_test_target
y_pred = predicted
precision_score(y_true, y_pred)
# Out:
# 0.81037367540435024

# %% [markdown]
# ##### Recall [Reference Link](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.recall_score.html)

# %%
from sklearn.metrics import recall_score
y_true = twenty_test_target
y_pred = predicted
recall_score(y_true, y_pred)
# Out:
# 0.9138364779874214

# %% [markdown]
# ##### Recall and precision of your classifier. [Reference Link](http://scikit-learn.org/stable/auto_examples/model_selection/plot_precision_recall.html)

# %%
# from sklearn.metrics import precision_recall_curve
# from sklearn.metrics import average_precision_score
# from sklearn.preprocessing import label_binarize
# X_train = X_train_lsi
# X_test = X_test_lsi
# y_train = twenty_train.target
# y_test = twenty_test.target
# y_score = clf_logistic_regression.predict_proba(X_test_lsi)[:, 1]
# y = label_binarize(twenty_train.target, classes=[0, 1])
# # n_classes = y.shape
# #print n_classes
# # Compute Precision-Recall and plot curve
# precision = dict()
# recall = dict()
# average_precision = dict()
# #for i in range(n_classes):
# precision, recall, _ = precision_recall_curve(y_test,y_score)    
# average_precision = average_precision_score(y_test, y_score)

# # print precision
# # print recall
# print average_precision

# %% [markdown]
# ### Problem (i)

# %%
from sklearn.multiclass import OneVsRestClassifier
from sklearn.multiclass import OneVsOneClassifier
#from sklearn.svm import LinearSVC
categories_i = ['comp.sys.ibm.pc.hardware','comp.sys.mac.hardware','misc.forsale','soc.religion.christian']
twenty_train_i = fetch_20newsgroups(subset='train', categories=categories_i, shuffle=True, random_state=42, remove = ('headers', 'footers','quotes'))
twenty_test_i = fetch_20newsgroups(subset='test', categories=categories_i, shuffle=True, random_state=42, remove = ('headers', 'footers','quotes'))
twenty_train_lsi_i = data_process(twenty_train_i)
twenty_test_lsi_i = data_process(twenty_test_i)
#OneVsRestClassifier(LinearSVC(random_state=0)).fit(X, y).predict(X)
#OneVsOneClassifier(LinearSVC(random_state=0)).fit(X, y).predict(X)

# %%
#y = label_binarize(y, classes=[0, 1, 2])
#n_classes = y.shape[1]

# %%
y = twenty_train_i.target
y = label_binarize(y, classes=[0, 1, 2, 3])
n_classes = y.shape[1]
#print n_classes
y_test = twenty_test_i.target
y_test = label_binarize(y_test, classes=[0, 1, 2, 3])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-bee835dbbb76> in <module>()
#       1 y = twenty_train_i.target
# ----> 2 y = label_binarize(y, classes=[0, 1, 2, 3])
#       3 n_classes = y.shape[1]
#       4 #print n_classes
#       5 y_test = twenty_test_i.target
#
# NameError: name 'label_binarize' is not defined

# %%
#print twenty_train_i.target

# %% [markdown]
# ##### One VS Rest

# %%
fit_i = OneVsRestClassifier(LinearSVC()).fit(twenty_train_lsi_i, twenty_train_i.target)
predict_i = fit_i.predict(twenty_test_lsi_i)
score = fit_i.score(twenty_test_lsi_i, twenty_test_i.target)
#predict_score = fit_i.decision_function(twenty_test_lsi_i)
print score
# Out:
# 0.493290734824

# %%
fpr = dict()
tpr = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i],predict_score[:, i])

#print precision
#print recall

print precision_score(twenty_test_i.target, predict_i,average='weighted')  
print recall_score(twenty_test_i.target, predict_i,average='weighted') 
print accuracy_score(twenty_test_i.target, predict_i)
print confusion_matrix(twenty_test_i.target, predict_i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-7cdc9375e207> in <module>()
#       1 fpr = dict()
#       2 tpr = dict()
# ----> 3 for i in range(n_classes):
#       4     fpr[i], tpr[i], _ = roc_curve(y_test[:, i],predict_score[:, i])
#       5
#
# NameError: name 'n_classes' is not defined

# %% [markdown]
# ##### One VS One

# %%
fit_i = OneVsOneClassifier(LinearSVC()).fit(twenty_train_lsi_i, twenty_train_i.target)
predict_i = fit_i.predict(twenty_test_lsi_i)
score = fit_i.score(twenty_test_lsi_i, twenty_test_i.target)
#predict_score = fit_i.decision_function(twenty_test_lsi_i)
print score
# Out:
# 0.497763578275

# %%
fpr = dict()
tpr = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i],predict_score[:, i])

#print precision
#print recall
print precision_score(twenty_test_i.target, predict_i,average='weighted')  
print recall_score(twenty_test_i.target, predict_i, average='weighted') 
print accuracy_score(twenty_test_i.target, predict_i)
print confusion_matrix(twenty_test_i.target, predict_i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-35af475e1d78> in <module>()
#       1 fpr = dict()
#       2 tpr = dict()
# ----> 3 for i in range(n_classes):
#       4     fpr[i], tpr[i], _ = roc_curve(y_test[:, i],predict_score[:, i])
#       5
#
# NameError: name 'n_classes' is not defined

# %% [markdown]
# ##### Naive bayes

# %%
clf_naive_bayes = GaussianNB().fit(twenty_train_lsi_i, twenty_train_i.target)
predicted = clf_naive_bayes.predict(twenty_test_lsi_i)
print predicted.shape
score = clf_naive_bayes.score(twenty_test_lsi_i, twenty_test_i.target)
print score

print precision_score(twenty_test_i.target, predicted,average='weighted')  
print recall_score(twenty_test_i.target, predicted,average='weighted') 
print accuracy_score(twenty_test_i.target, predicted)
print confusion_matrix(twenty_test_i.target, predicted)
# Out:
# (1565,)
# 0.461341853035
# 0.455616902111
# 0.461341853035
# 0.461341853035
# [[123 184  51  34]
#  [120 118  79  68]
#  [ 92  70 171  57]
#  [ 46  23  19 310]]
